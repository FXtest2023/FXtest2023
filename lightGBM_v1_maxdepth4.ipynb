# %% [markdown]
# <a href="https://colab.research.google.com/github/FXtest2023/FXtest2023/blob/main/lightGBM_v1_maxdepth4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas_ta
# !pip install optuna
# Out:
# Collecting pandas_ta
#   Downloading pandas_ta-0.3.14b.tar.gz (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.1/115.1 kB 3.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from pandas_ta) (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->pandas_ta) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->pandas_ta) (2022.7.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas->pandas_ta) (1.22.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->pandas_ta) (1.16.0)
# Building wheels for collected packages: pandas_ta
#   Building wheel for pandas_ta (setup.py) ... done
#   Created wheel for pandas_ta: filename=pandas_ta-0.3.14b0-py3-none-any.whl size=218908 sha256=fb12d32ab86ca2a9e5ca408acd288aa13f82387bc8d1dbd535024ddda68a1c55
#   Stored in directory: /root/.cache/pip/wheels/69/00/ac/f7fa862c34b0e2ef320175100c233377b4c558944f12474cf0
# Successfully built pandas_ta
# Installing collected packages: pandas_ta
# Successfully installed pandas_ta-0.3.14b0
# Collecting optuna
#   Downloading optuna-3.2.0-py3-none-any.whl (390 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 390.6/390.6 kB 5.9 MB/s eta 0:00:00
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.11.1-py3-none-any.whl (224 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 16.7 MB/s eta 0:00:00
# Collecting cmaes>=0.9.1 (from optuna)
#   Downloading cmaes-0.9.1-py3-none-any.whl (21 kB)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.7.0-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from optuna) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (23.1)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (2.0.18)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from optuna) (4.65.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from optuna) (6.0)
# Collecting Mako (from alembic>=1.5.0->optuna)
#   Downloading Mako-1.2.4-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.7/78.7 kB 8.6 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (4.7.1)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.3.0->optuna) (2.0.2)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from Mako->alembic>=1.5.0->optuna) (2.1.3)
# Installing collected packages: Mako, colorlog, cmaes, alembic, optuna
# Successfully installed Mako-1.2.4 alembic-1.11.1 cmaes-0.9.1 colorlog-6.7.0 optuna-3.2.0

# %%
from google.colab import files
import pandas as pd
import matplotlib.pyplot as plt
import pandas_ta as pd_ta
from sklearn.model_selection import KFold
from optuna.integration import lightgbm as lgb
#import lightgbm as lgb
from sklearn.metrics import confusion_matrix
import seaborn as sns
from sklearn.metrics import accuracy_score
import numpy as np
from sklearn.metrics import log_loss
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import RepeatedKFold

# %%
url = "https://raw.githubusercontent.com/FXtest2023/FXtest2023/5167452d53ac943d8cdb8218a7604a8b530bf465/USDJPY_1H.csv"
df_1H = pd.read_csv(url)

# %%
df_1H
# Out:
#                     utc_datetime  bid_open  bid_high  bid_low  bid_close
# 0      2015-01-01 23:00:00+00:00   119.748   119.819  119.737    119.810
# 1      2015-01-02 00:00:00+00:00   119.809   119.946  119.791    119.866
# 2      2015-01-02 01:00:00+00:00   119.874   120.048  119.831    120.048
# 3      2015-01-02 02:00:00+00:00   120.055   120.382  120.039    120.273
# 4      2015-01-02 03:00:00+00:00   120.266   120.400  120.261    120.325
# ...                          ...       ...       ...      ...        ...
# 52567  2023-07-06 21:00:00+00:00   144.081   144.112  144.040    144.044
# 52568  2023-07-06 22:00:00+00:00   144.023   144.056  143.975    144.005
# 52569  2023-07-06 23:00:00+00:00   144.014   144.049  144.014    144.040
# 52570  2023-07-07 00:00:00+00:00   144.045   144.045  143.881    143.933
# 52571  2023-07-07 01:00:00+00:00   143.952   144.171  143.794    144.067
#
# [52572 rows x 5 columns]

# %%
def calc_features(df):
    open = df['bid_open']
    high = df['bid_high']
    low = df['bid_low']
    close = df['bid_close']
 #   volume = df['volume']

    orig_columns = df.columns

    hilo = (df['bid_high'] + df['bid_low']) / 2
    # 価格(hilo または close)を引いた後、価格(close)で割ることで標準化

    bbands_df = pd_ta.bbands(close, timeperiod=5, nbdevup=2, nbdevdn=2, matype=0)
    df['BBANDS_upperband'] = (bbands_df.iloc[:, 2] - hilo) / close
    df['BBANDS_middleband'] = (bbands_df.iloc[:, 1] - hilo) / close
    df['BBANDS_lowerband'] = (bbands_df.iloc[:, 0] - hilo) / close
    df['DEMA'] = (pd_ta.dema(close, timeperiod=30) - hilo) / close
    df['EMA'] = (pd_ta.ema(close, timeperiod=30) - hilo) / close

#    https://github.com/twopirllc/pandas-ta/issues/411
#    df['HT_TRENDLINE'] = (pd_ta.HT_TRENDLINE(close) - hilo) / close
    df['KAMA'] = (pd_ta.kama(close, timeperiod=30) - hilo) / close
    df['MIDPOINT'] = (pd_ta.midpoint(close, timeperiod=14) - hilo) / close
    df['SMA'] = (pd_ta.sma(close, timeperiod=30) - hilo) / close
    df['T3'] = (pd_ta.t3(close, timeperiod=5, vfactor=0) - hilo) / close
    df['TEMA'] = (pd_ta.tema(close, timeperiod=30) - hilo) / close
    df['TRIMA'] = (pd_ta.trima(close, timeperiod=30) - hilo) / close
    df['WMA'] = (pd_ta.wma(close, timeperiod=30) - hilo) / close
#    df['LINEARREG'] = (pd_ta.LINEARREG(close, timeperiod=14) - close) / close
#    df['LINEARREG_INTERCEPT'] = (pd_ta.LINEARREG_INTERCEPT(close, timeperiod=14) - close) / close


    # 価格(close)で割ることで標準化
#    df['AD'] = pd_ta.AD(high, low, close, volume) / close
#    df['ADOSC'] = pd_ta.ADOSC(high, low, close, volume, fastperiod=3, slowperiod=10) / close
    df['APO'] = pd_ta.apo(close, fastperiod=12, slowperiod=26, matype=0) / close
#    df['HT_PHASOR_inphase'], df['HT_PHASOR_quadrature'] = pd_ta.HT_PHASOR(close)
#    df['HT_PHASOR_inphase'] /= close
#    df['HT_PHASOR_quadrature'] /= close
    df['LINEARREG_SLOPE'] = pd_ta.slope(close, timeperiod=14) / close
    macd = pd_ta.macd(close, fastperiod=12, slowperiod=26, signalperiod=9)
    df['MACD_macd'] = macd.iloc[:, 0] / close
    df['MACD_macdsignal'] =  macd.iloc[:, 1] / close
    df['MACD_macdhist'] =  macd.iloc[:, 2] / close
#    df['MINUS_DM'] = pd_ta.MINUS_DM(high, low, timeperiod=14) / close
    df['MOM'] = pd_ta.mom(close, timeperiod=10) / close
#    df['OBV'] = pd_ta.OBV(close, volume) / close
#    df['PLUS_DM'] = pd_ta.PLUS_DM(high, low, timeperiod=14) / close
    df['STDEV'] = pd_ta.stdev(close, timeperiod=5, nbdev=1) / close
#    df['TRANGE'] = pd_ta.TRANGE(high, low, close) / close


    df['ADX'] = pd_ta.adx(high, low, close, timeperiod=14).iloc[:, 0] / 100
#    df['ADXR'] = pd_ta.ADXR(high, low, close, timeperiod=14)
    aroon = pd_ta.aroon(high, low, timeperiod=14)
    df['AROON_aroondown'] = aroon.iloc[:, 0] / 100
    df['AROON_aroonup'] = aroon.iloc[:, 1] / 100
#    df['AROONOSC'] = pd_ta.AROONOSC(high, low, timeperiod=14)
    df['BOP'] = pd_ta.bop(open, high, low, close)
    df['CCI'] = pd_ta.cci(high, low, close, timeperiod=14) / 100
#    df['DX'] = pd_ta.DX(high, low, close, timeperiod=14)
    # skip MACDEXT MACDFIX たぶん同じなので
#    df['MFI'] = pd_ta.MFI(high, low, close, volume, timeperiod=14)
#    df['MINUS_DI'] = pd_ta.MINUS_DI(high, low, close, timeperiod=14)
#    df['PLUS_DI'] = pd_ta.PLUS_DI(high, low, close, timeperiod=14)
    df['RSI'] = pd_ta.rsi(close, timeperiod=14) / 100

    stoch = pd_ta.stoch(high, low, close, fastk_period=5, slowk_period=3, slowk_matype=0, slowd_period=3, slowd_matype=0)
    df['STOCH_slowk'] = stoch.iloc[:, 0] / 100
    df['STOCH_slowd'] = stoch.iloc[:, 1] / 100

#    df['STOCHF_fastk'], df['STOCHF_fastd'] = pd_ta.STOCHF(high, low, close, fastk_period=5, fastd_period=3, fastd_matype=0)
    stochrsi = pd_ta.stochrsi(close, timeperiod=14, fastk_period=5, fastd_period=3, fastd_matype=0)

    df['STOCHRSI_fastk'] = stochrsi.iloc[:, 0] / 100
    df['STOCHRSI_fastd'] = stochrsi.iloc[:, 1] / 100

    df['TRIX'] = pd_ta.trix(close, timeperiod=30).iloc[:, 1]
#    df['ULTOSC'] = pd_ta.ULTOSC(high, low, close, timeperiod1=7, timeperiod2=14, timeperiod3=28)
    df['WILLR'] = pd_ta.willr(high, low, close, timeperiod=14) / 100

    df['ATR'] = pd_ta.atr(high, low, close, timeperiod=14)
    df['NATR'] = pd_ta.natr(high, low, close, timeperiod=14)

#    df['HT_DCPERIOD'] = pd_ta.HT_DCPERIOD(close)
#    df['HT_DCPHASE'] = pd_ta.HT_DCPHASE(close)
#    df['HT_SINE_sine'], df['HT_SINE_leadsine'] = pd_ta.HT_SINE(close)
#    df['HT_TRENDMODE'] = pd_ta.HT_TRENDMODE(close)

#    df['BETA'] = pd_ta.BETA(high, low, timeperiod=5)
#    df['CORREL'] = pd_ta.cti(high, low, timeperiod=30)

#    df['LINEARREG_ANGLE'] = pd_ta.LINEARREG_ANGLE(close, timeperiod=14)
    return df

df = calc_features(df_1H)
df.dropna(inplace=True)
# df.to_csv('output.csv', index=False, encoding = 'utf-8-sig')
# files.download('output.csv')

# %%
df['diff']  = df['bid_close'].shift(-1) - df['bid_close']
df['label'] = df['diff'].apply(lambda x: 1 if x>0 else 0 )
df.dropna(inplace=True)
df.reset_index(drop=True,inplace=True)
df
# Out:
#                     utc_datetime  bid_open  bid_high  bid_low  bid_close  \
# 0      2015-01-05 13:00:00+00:00   120.257   120.257  120.040    120.118
# 1      2015-01-05 14:00:00+00:00   120.142   120.156  119.758    119.806
# 2      2015-01-05 15:00:00+00:00   119.810   119.814  119.497    119.506
# 3      2015-01-05 16:00:00+00:00   119.471   119.644  119.406    119.624
# 4      2015-01-05 17:00:00+00:00   119.581   119.744  119.443    119.639
# ...                          ...       ...       ...      ...        ...
# 52528  2023-07-06 20:00:00+00:00   144.124   144.137  144.061    144.085
# 52529  2023-07-06 21:00:00+00:00   144.081   144.112  144.040    144.044
# 52530  2023-07-06 22:00:00+00:00   144.023   144.056  143.975    144.005
# 52531  2023-07-06 23:00:00+00:00   144.014   144.049  144.014    144.040
# 52532  2023-07-07 00:00:00+00:00   144.045   144.045  143.881    143.933
#
#        BBANDS_upperband  BBANDS_middleband  BBANDS_lowerband      DEMA  \
# 0              0.002313           0.000843         -0.000626  0.000675
# 1              0.004584           0.001536         -0.001512  0.001027
# 2              0.008033           0.002901         -0.002230  0.001810
# 3              0.007470           0.002785         -0.001900  0.001958
# 4              0.004764           0.001213         -0.002338  0.000760
# ...                 ...                ...               ...       ...
# 52528          0.000512           0.000028         -0.000457 -0.000010
# 52529          0.000719           0.000149         -0.000422  0.000030
# 52530          0.001239           0.000465         -0.000310  0.000272
# 52531          0.000686           0.000176         -0.000335  0.000111
# 52532          0.001114           0.000406         -0.000302  0.000306
#
#             EMA  ...  STOCH_slowk  STOCH_slowd  STOCHRSI_fastk  \
# 0      0.001203  ...     0.375531     0.424923        0.164391
# 1      0.002066  ...     0.209280     0.334552        0.042169
# 2      0.003531  ...     0.085086     0.223299        0.000000
# 3      0.003929  ...     0.082355     0.125574        0.052231
# 4      0.002815  ...     0.128304     0.098582        0.111039
# ...         ...  ...          ...          ...             ...
# 52528 -0.000032  ...     0.531073     0.526051        0.828761
# 52529  0.000064  ...     0.492153     0.517577        0.751853
# 52530  0.000383  ...     0.448063     0.490430        0.675739
# 52531  0.000233  ...     0.423441     0.454552        0.655306
# 52532  0.000542  ...     0.376162     0.415889        0.593326
#
#        STOCHRSI_fastd      TRIX     WILLR       ATR      NATR   diff  label
# 0            0.165157  0.000116 -0.809683  0.188649  0.159261 -0.312      0
# 1            0.123650  0.000096 -0.943195  0.204482  0.182680 -0.300      0
# 2            0.068853  0.000034 -0.991863  0.212957  0.194088  0.118      1
# 3            0.031467 -0.000080 -0.817878  0.214835  0.194571  0.015      1
# 4            0.054423 -0.000254 -0.805347  0.221277  0.202152 -0.078      0
# ...               ...       ...       ...       ...       ...    ...    ...
# 52528        0.836126 -0.004319 -0.502825  0.214143  0.149312 -0.041      0
# 52529        0.809364 -0.004510 -0.541431  0.203990  0.136105 -0.039      0
# 52530        0.752118 -0.004671 -0.611554  0.195205  0.125490  0.035      1
# 52531        0.694299 -0.004809 -0.576693  0.184405  0.112804 -0.107      0
# 52532        0.641457 -0.004932 -0.683267  0.182947  0.113028  0.134      1
#
# [52533 rows x 40 columns]

# %%
len(df[df['label']==1])
# Out:
# 26652

# %%
len(df[df['label']==0])
# Out:
# 25881

# %%
df_train = df[ : 40000]
df_test  = df[40000 : ]

# %%
drop_cols = ['utc_datetime','bid_open',	'bid_high',	'bid_low','bid_close', 'diff','label']
X_train=df_train.drop(columns=drop_cols).values
Y_train=df_train['label'].values
Y_train = Y_train.reshape(-1)

X_test=df_test.drop(columns=drop_cols).values
Y_test=df_test['label'].values
Y_test = Y_test.reshape(-1)

# %%
# 乱数シードの固定
SEED = 123

# LightGBM訓練用関数を定義
def trainGbdt(X_train, y_train):
    bests = []
    kf = KFold(n_splits=5, shuffle=False)
    for learn_index, valid_index in kf.split(X_train, y_train):
        X_learn, X_valid = X_train[learn_index], X_train[valid_index]
        y_learn, y_valid = y_train[learn_index], y_train[valid_index]

        #LGB用のデータに変形
        lgb_learn = lgb.Dataset(X_learn, y_learn)
        lgb_valid = lgb.Dataset(X_valid, y_valid)

        param = {
            'objective': 'binary',
            'metric': 'auc',
            'boosting_type': 'gbdt',
            'random_seed':SEED,
            'max_depth':4,
            'verbose':-1,
#            'device': 'gpu',
 #           'force_col_wise': True,
        }

        # 訓練実施
        best = lgb.train(param,
                         lgb_learn,
                         valid_sets=[lgb_learn,lgb_valid],
                         verbose_eval=False
                        )
        bests.append(best)

    return bests

# %%
bests_ = trainGbdt(X_train, Y_train)
# Out:
# [I 2023-07-12 09:43:50,996] A new study created in memory with name: no-name-1eb26635-3a4c-45b5-a271-b030c99ddea6
# feature_fraction, val_score: -inf:   0%|          | 0/7 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# feature_fraction, val_score: 0.512187:  14%|#4        | 1/7 [00:26<02:38, 26.44s/it][I 2023-07-12 09:44:17,449] Trial 0 finished with value: 0.5121866929885684 and parameters: {'feature_fraction': 0.7}. Best is trial 0 with value: 0.5121866929885684.
# feature_fraction, val_score: 0.520907:  29%|##8       | 2/7 [00:36<01:25, 17.01s/it][I 2023-07-12 09:44:27,855] Trial 1 finished with value: 0.5209070105315109 and parameters: {'feature_fraction': 0.8}. Best is trial 1 with value: 0.5209070105315109.
# feature_fraction, val_score: 0.520907:  43%|####2     | 3/7 [00:46<00:54, 13.66s/it][I 2023-07-12 09:44:37,544] Trial 2 finished with value: 0.5142069639531456 and parameters: {'feature_fraction': 0.6}. Best is trial 1 with value: 0.5209070105315109.
# feature_fraction, val_score: 0.520907:  57%|#####7    | 4/7 [00:57<00:37, 12.57s/it][I 2023-07-12 09:44:48,425] Trial 3 finished with value: 0.5152856043849168 and parameters: {'feature_fraction': 1.0}. Best is trial 1 with value: 0.5209070105315109.
# feature_fraction, val_score: 0.520907:  71%|#######1  | 5/7 [01:04<00:21, 10.51s/it][I 2023-07-12 09:44:55,289] Trial 4 finished with value: 0.5207255599217043 and parameters: {'feature_fraction': 0.4}. Best is trial 1 with value: 0.5209070105315109.
# feature_fraction, val_score: 0.520907:  86%|########5 | 6/7 [01:15<00:10, 10.60s/it][I 2023-07-12 09:45:06,052] Trial 5 finished with value: 0.5183947040173652 and parameters: {'feature_fraction': 0.8999999999999999}. Best is trial 1 with value: 0.5209070105315109.
# feature_fraction, val_score: 0.520907: 100%|##########| 7/7 [01:25<00:00, 10.57s/it][I 2023-07-12 09:45:16,574] Trial 6 finished with value: 0.5163538065625242 and parameters: {'feature_fraction': 0.5}. Best is trial 1 with value: 0.5209070105315109.
# feature_fraction, val_score: 0.520907: 100%|##########| 7/7 [01:25<00:00, 12.22s/it]
# num_leaves, val_score: 0.521633:   5%|5         | 1/20 [00:06<02:04,  6.57s/it][I 2023-07-12 09:45:23,160] Trial 7 finished with value: 0.5216325629526734 and parameters: {'num_leaves': 4}. Best is trial 7 with value: 0.5216325629526734.
# num_leaves, val_score: 0.521633:  10%|#         | 2/20 [00:15<02:20,  7.83s/it][I 2023-07-12 09:45:31,875] Trial 8 finished with value: 0.5192090128511785 and parameters: {'num_leaves': 6}. Best is trial 7 with value: 0.5216325629526734.
# num_leaves, val_score: 0.521633:  15%|#5        | 3/20 [00:25<02:31,  8.93s/it][I 2023-07-12 09:45:42,114] Trial 9 finished with value: 0.5209070105315109 and parameters: {'num_leaves': 16}. Best is trial 7 with value: 0.5216325629526734.
# num_leaves, val_score: 0.521633:  20%|##        | 4/20 [00:35<02:28,  9.29s/it][I 2023-07-12 09:45:51,963] Trial 10 finished with value: 0.5205183574513259 and parameters: {'num_leaves': 2}. Best is trial 7 with value: 0.5216325629526734.
# num_leaves, val_score: 0.521633:  25%|##5       | 5/20 [00:42<02:06,  8.46s/it][I 2023-07-12 09:45:58,947] Trial 11 finished with value: 0.5212862879343032 and parameters: {'num_leaves': 8}. Best is trial 7 with value: 0.5216325629526734.
# num_leaves, val_score: 0.521633:  30%|###       | 6/20 [00:51<02:01,  8.68s/it][I 2023-07-12 09:46:08,040] Trial 12 finished with value: 0.5212862879343032 and parameters: {'num_leaves': 8}. Best is trial 7 with value: 0.5216325629526734.
# num_leaves, val_score: 0.521633:  35%|###5      | 7/20 [01:00<01:52,  8.64s/it][I 2023-07-12 09:46:16,621] Trial 13 finished with value: 0.5216325629526734 and parameters: {'num_leaves': 4}. Best is trial 7 with value: 0.5216325629526734.
# num_leaves, val_score: 0.521633:  40%|####      | 8/20 [01:05<01:33,  7.77s/it][I 2023-07-12 09:46:22,521] Trial 14 finished with value: 0.5205183574513259 and parameters: {'num_leaves': 2}. Best is trial 7 with value: 0.5216325629526734.
# num_leaves, val_score: 0.525005:  45%|####5     | 9/20 [01:14<01:28,  8.07s/it][I 2023-07-12 09:46:31,258] Trial 15 finished with value: 0.5250054316424362 and parameters: {'num_leaves': 5}. Best is trial 15 with value: 0.5250054316424362.
# num_leaves, val_score: 0.525005:  50%|#####     | 10/20 [01:24<01:25,  8.58s/it][I 2023-07-12 09:46:40,972] Trial 16 finished with value: 0.5180958699266022 and parameters: {'num_leaves': 11}. Best is trial 15 with value: 0.5250054316424362.
# num_leaves, val_score: 0.525005:  55%|#####5    | 11/20 [01:31<01:12,  8.00s/it][I 2023-07-12 09:46:47,665] Trial 17 finished with value: 0.5250054316424362 and parameters: {'num_leaves': 5}. Best is trial 15 with value: 0.5250054316424362.
# num_leaves, val_score: 0.525005:  60%|######    | 12/20 [01:40<01:08,  8.54s/it][I 2023-07-12 09:46:57,423] Trial 18 finished with value: 0.5180958699266022 and parameters: {'num_leaves': 11}. Best is trial 15 with value: 0.5250054316424362.
# num_leaves, val_score: 0.525005:  65%|######5   | 13/20 [01:49<01:00,  8.66s/it][I 2023-07-12 09:47:06,364] Trial 19 finished with value: 0.5192090128511785 and parameters: {'num_leaves': 6}. Best is trial 15 with value: 0.5250054316424362.
# num_leaves, val_score: 0.525005:  70%|#######   | 14/20 [01:56<00:48,  8.06s/it][I 2023-07-12 09:47:13,037] Trial 20 finished with value: 0.5250054316424362 and parameters: {'num_leaves': 5}. Best is trial 15 with value: 0.5250054316424362.
# num_leaves, val_score: 0.525005:  75%|#######5  | 15/20 [02:05<00:41,  8.27s/it][I 2023-07-12 09:47:21,804] Trial 21 finished with value: 0.5250054316424362 and parameters: {'num_leaves': 5}. Best is trial 15 with value: 0.5250054316424362.
# num_leaves, val_score: 0.525005:  80%|########  | 16/20 [02:14<00:33,  8.49s/it][I 2023-07-12 09:47:30,803] Trial 22 finished with value: 0.5240686764618744 and parameters: {'num_leaves': 7}. Best is trial 15 with value: 0.5250054316424362.
# num_leaves, val_score: 0.525005:  85%|########5 | 17/20 [02:21<00:24,  8.17s/it][I 2023-07-12 09:47:38,239] Trial 23 finished with value: 0.516175731196579 and parameters: {'num_leaves': 10}. Best is trial 15 with value: 0.5250054316424362.
# num_leaves, val_score: 0.525005:  90%|######### | 18/20 [02:30<00:16,  8.30s/it][I 2023-07-12 09:47:46,821] Trial 24 finished with value: 0.5216325629526734 and parameters: {'num_leaves': 4}. Best is trial 15 with value: 0.5250054316424362.
# num_leaves, val_score: 0.525005:  95%|#########5| 19/20 [02:38<00:08,  8.32s/it][I 2023-07-12 09:47:55,213] Trial 25 finished with value: 0.5214069216500892 and parameters: {'num_leaves': 3}. Best is trial 15 with value: 0.5250054316424362.
# num_leaves, val_score: 0.525005: 100%|##########| 20/20 [02:45<00:00,  7.84s/it][I 2023-07-12 09:48:01,941] Trial 26 finished with value: 0.5192090128511785 and parameters: {'num_leaves': 6}. Best is trial 15 with value: 0.5250054316424362.
# num_leaves, val_score: 0.525005: 100%|##########| 20/20 [02:45<00:00,  8.27s/it]
# bagging, val_score: 0.525005:  10%|#         | 1/10 [00:09<01:21,  9.00s/it][I 2023-07-12 09:48:10,964] Trial 27 finished with value: 0.5210430203582209 and parameters: {'bagging_fraction': 0.7194291061397695, 'bagging_freq': 3}. Best is trial 27 with value: 0.5210430203582209.
# bagging, val_score: 0.525005:  20%|##        | 2/10 [00:17<01:08,  8.62s/it][I 2023-07-12 09:48:19,311] Trial 28 finished with value: 0.5103201831332314 and parameters: {'bagging_fraction': 0.40929063668579985, 'bagging_freq': 7}. Best is trial 27 with value: 0.5210430203582209.
# bagging, val_score: 0.525005:  30%|###       | 3/10 [00:24<00:55,  7.96s/it][I 2023-07-12 09:48:26,490] Trial 29 finished with value: 0.5194142151770466 and parameters: {'bagging_fraction': 0.9570336468071907, 'bagging_freq': 1}. Best is trial 27 with value: 0.5210430203582209.
# bagging, val_score: 0.525005:  40%|####      | 4/10 [00:32<00:48,  8.15s/it][I 2023-07-12 09:48:34,926] Trial 30 finished with value: 0.5103038694545681 and parameters: {'bagging_fraction': 0.41925792725256317, 'bagging_freq': 7}. Best is trial 27 with value: 0.5210430203582209.
# bagging, val_score: 0.525005:  50%|#####     | 5/10 [00:42<00:42,  8.59s/it][I 2023-07-12 09:48:44,294] Trial 31 finished with value: 0.5243785113474448 and parameters: {'bagging_fraction': 0.9954086974651468, 'bagging_freq': 4}. Best is trial 31 with value: 0.5243785113474448.
# bagging, val_score: 0.525005:  60%|######    | 6/10 [00:49<00:32,  8.03s/it][I 2023-07-12 09:48:51,242] Trial 32 finished with value: 0.5172278072090708 and parameters: {'bagging_fraction': 0.6543278829680924, 'bagging_freq': 1}. Best is trial 31 with value: 0.5243785113474448.
# bagging, val_score: 0.525005:  70%|#######   | 7/10 [00:58<00:25,  8.39s/it][I 2023-07-12 09:49:00,374] Trial 33 finished with value: 0.5206896823295483 and parameters: {'bagging_fraction': 0.8032378098773612, 'bagging_freq': 5}. Best is trial 31 with value: 0.5243785113474448.
# bagging, val_score: 0.525005:  80%|########  | 8/10 [01:07<00:16,  8.48s/it][I 2023-07-12 09:49:09,044] Trial 34 finished with value: 0.5110274842357361 and parameters: {'bagging_fraction': 0.5307888728814891, 'bagging_freq': 5}. Best is trial 31 with value: 0.5243785113474448.
# bagging, val_score: 0.525005:  90%|######### | 9/10 [01:14<00:08,  8.11s/it][I 2023-07-12 09:49:16,331] Trial 35 finished with value: 0.5209726402732597 and parameters: {'bagging_fraction': 0.8585006155603869, 'bagging_freq': 3}. Best is trial 31 with value: 0.5243785113474448.
# bagging, val_score: 0.525005: 100%|##########| 10/10 [01:25<00:00,  8.94s/it][I 2023-07-12 09:49:27,145] Trial 36 finished with value: 0.5173409403829426 and parameters: {'bagging_fraction': 0.5943012055065761, 'bagging_freq': 6}. Best is trial 31 with value: 0.5243785113474448.
# bagging, val_score: 0.525005: 100%|##########| 10/10 [01:25<00:00,  8.52s/it]
# feature_fraction_stage2, val_score: 0.525005:  17%|#6        | 1/6 [00:08<00:43,  8.68s/it][I 2023-07-12 09:49:35,840] Trial 37 finished with value: 0.5250054316424362 and parameters: {'feature_fraction': 0.784}. Best is trial 37 with value: 0.5250054316424362.
# feature_fraction_stage2, val_score: 0.525005:  33%|###3      | 2/6 [00:15<00:30,  7.57s/it][I 2023-07-12 09:49:42,626] Trial 38 finished with value: 0.5199701303419172 and parameters: {'feature_fraction': 0.8480000000000001}. Best is trial 37 with value: 0.5250054316424362.
# feature_fraction_stage2, val_score: 0.525005:  50%|#####     | 3/6 [00:24<00:24,  8.19s/it][I 2023-07-12 09:49:51,551] Trial 39 finished with value: 0.5237859685362267 and parameters: {'feature_fraction': 0.88}. Best is trial 37 with value: 0.5250054316424362.
# feature_fraction_stage2, val_score: 0.525005:  67%|######6   | 4/6 [00:33<00:16,  8.39s/it][I 2023-07-12 09:50:00,257] Trial 40 finished with value: 0.5224204323762391 and parameters: {'feature_fraction': 0.7520000000000001}. Best is trial 37 with value: 0.5250054316424362.
# feature_fraction_stage2, val_score: 0.525005:  83%|########3 | 5/6 [00:39<00:07,  7.81s/it][I 2023-07-12 09:50:07,047] Trial 41 finished with value: 0.5223540525802989 and parameters: {'feature_fraction': 0.8160000000000001}. Best is trial 37 with value: 0.5250054316424362.
# feature_fraction_stage2, val_score: 0.525005: 100%|##########| 6/6 [00:48<00:00,  8.07s/it][I 2023-07-12 09:50:15,606] Trial 42 finished with value: 0.5189526193267464 and parameters: {'feature_fraction': 0.7200000000000001}. Best is trial 37 with value: 0.5250054316424362.
# feature_fraction_stage2, val_score: 0.525005: 100%|##########| 6/6 [00:48<00:00,  8.08s/it]
# regularization_factors, val_score: 0.525005:   5%|5         | 1/20 [00:08<02:49,  8.94s/it][I 2023-07-12 09:50:24,564] Trial 43 finished with value: 0.5201940840225706 and parameters: {'lambda_l1': 1.4167481143392657e-05, 'lambda_l2': 2.95650765209977}. Best is trial 43 with value: 0.5201940840225706.
# regularization_factors, val_score: 0.525005:  10%|#         | 2/20 [00:15<02:20,  7.80s/it][I 2023-07-12 09:50:31,562] Trial 44 finished with value: 0.5202485879604801 and parameters: {'lambda_l1': 2.7127235457438372, 'lambda_l2': 1.2488683603000102e-08}. Best is trial 44 with value: 0.5202485879604801.
# regularization_factors, val_score: 0.525005:  15%|#5        | 3/20 [00:24<02:20,  8.28s/it][I 2023-07-12 09:50:40,425] Trial 45 finished with value: 0.5240340489600374 and parameters: {'lambda_l1': 3.7177470269076546e-08, 'lambda_l2': 0.0007254137486120157}. Best is trial 45 with value: 0.5240340489600374.
# regularization_factors, val_score: 0.525005:  20%|##        | 4/20 [00:34<02:19,  8.71s/it][I 2023-07-12 09:50:49,798] Trial 46 finished with value: 0.5172714978657208 and parameters: {'lambda_l1': 7.366227626108434, 'lambda_l2': 5.8680551818709476e-08}. Best is trial 45 with value: 0.5240340489600374.
# regularization_factors, val_score: 0.525352:  25%|##5       | 5/20 [00:41<02:01,  8.09s/it][I 2023-07-12 09:50:56,775] Trial 47 finished with value: 0.5253521441924179 and parameters: {'lambda_l1': 0.004109325587715238, 'lambda_l2': 4.802872067059649}. Best is trial 47 with value: 0.5253521441924179.
# regularization_factors, val_score: 0.525352:  30%|###       | 6/20 [00:50<01:57,  8.41s/it][I 2023-07-12 09:51:05,824] Trial 48 finished with value: 0.5217764483483932 and parameters: {'lambda_l1': 0.0028900954409439295, 'lambda_l2': 9.648508548053565}. Best is trial 47 with value: 0.5253521441924179.
# regularization_factors, val_score: 0.525352:  35%|###5      | 7/20 [00:59<01:51,  8.59s/it][I 2023-07-12 09:51:14,782] Trial 49 finished with value: 0.5221516004531327 and parameters: {'lambda_l1': 0.0032774766287375977, 'lambda_l2': 0.03881683542193952}. Best is trial 47 with value: 0.5253521441924179.
# regularization_factors, val_score: 0.525352:  40%|####      | 8/20 [01:06<01:36,  8.05s/it][I 2023-07-12 09:51:21,672] Trial 50 finished with value: 0.5217922619909289 and parameters: {'lambda_l1': 5.641957339141643e-05, 'lambda_l2': 0.055288063514049295}. Best is trial 47 with value: 0.5253521441924179.
# regularization_factors, val_score: 0.525352:  45%|####5     | 9/20 [01:15<01:31,  8.34s/it][I 2023-07-12 09:51:30,649] Trial 51 finished with value: 0.5226255096930753 and parameters: {'lambda_l1': 0.07301283452067861, 'lambda_l2': 9.174355939294408e-06}. Best is trial 47 with value: 0.5253521441924179.
# regularization_factors, val_score: 0.526973:  50%|#####     | 10/20 [01:23<01:24,  8.48s/it][I 2023-07-12 09:51:39,430] Trial 52 finished with value: 0.5269730738045824 and parameters: {'lambda_l1': 2.072449649944807e-06, 'lambda_l2': 0.11364960003428355}. Best is trial 52 with value: 0.5269730738045824.
# regularization_factors, val_score: 0.526973:  55%|#####5    | 11/20 [01:30<01:11,  7.97s/it][I 2023-07-12 09:51:46,244] Trial 53 finished with value: 0.5227500186888503 and parameters: {'lambda_l1': 3.155012474390659e-06, 'lambda_l2': 0.28955404103677745}. Best is trial 52 with value: 0.5269730738045824.
# regularization_factors, val_score: 0.526973:  60%|######    | 12/20 [01:39<01:05,  8.23s/it][I 2023-07-12 09:51:55,062] Trial 54 finished with value: 0.5252130716444263 and parameters: {'lambda_l1': 1.374052593438213e-07, 'lambda_l2': 0.3005398911378757}. Best is trial 52 with value: 0.5269730738045824.
# regularization_factors, val_score: 0.526973:  65%|######5   | 13/20 [01:48<00:59,  8.45s/it][I 2023-07-12 09:52:04,033] Trial 55 finished with value: 0.5231474224012685 and parameters: {'lambda_l1': 1.752292876664924e-07, 'lambda_l2': 0.5286002999324441}. Best is trial 52 with value: 0.5269730738045824.
# regularization_factors, val_score: 0.526973:  70%|#######   | 14/20 [01:55<00:47,  7.95s/it][I 2023-07-12 09:52:10,813] Trial 56 finished with value: 0.5219495858575782 and parameters: {'lambda_l1': 1.2577029154460481e-06, 'lambda_l2': 0.01562630481350717}. Best is trial 52 with value: 0.5269730738045824.
# regularization_factors, val_score: 0.526973:  75%|#######5  | 15/20 [02:04<00:41,  8.27s/it][I 2023-07-12 09:52:19,826] Trial 57 finished with value: 0.5212104699564544 and parameters: {'lambda_l1': 1.09076066990182e-08, 'lambda_l2': 1.1532921901063808}. Best is trial 52 with value: 0.5269730738045824.
# regularization_factors, val_score: 0.526973:  80%|########  | 16/20 [02:13<00:33,  8.48s/it][I 2023-07-12 09:52:28,815] Trial 58 finished with value: 0.5204634784863207 and parameters: {'lambda_l1': 4.299714852214111e-07, 'lambda_l2': 5.865095367207399}. Best is trial 52 with value: 0.5269730738045824.
# regularization_factors, val_score: 0.526973:  85%|########5 | 17/20 [02:19<00:23,  7.97s/it][I 2023-07-12 09:52:35,580] Trial 59 finished with value: 0.522248794975437 and parameters: {'lambda_l1': 1.650650947835152e-05, 'lambda_l2': 0.2077275518333727}. Best is trial 52 with value: 0.5269730738045824.
# regularization_factors, val_score: 0.526973:  90%|######### | 18/20 [02:28<00:16,  8.24s/it][I 2023-07-12 09:52:44,444] Trial 60 finished with value: 0.5240420495380791 and parameters: {'lambda_l1': 1.8489149493787964e-07, 'lambda_l2': 0.007690942651809878}. Best is trial 52 with value: 0.5269730738045824.
# regularization_factors, val_score: 0.526973:  95%|#########5| 19/20 [02:37<00:08,  8.45s/it][I 2023-07-12 09:52:53,376] Trial 61 finished with value: 0.5197192997194048 and parameters: {'lambda_l1': 0.00029174676608841683, 'lambda_l2': 0.703912468393731}. Best is trial 52 with value: 0.5269730738045824.
# regularization_factors, val_score: 0.526973: 100%|##########| 20/20 [02:44<00:00,  8.00s/it][I 2023-07-12 09:53:00,330] Trial 62 finished with value: 0.522039654865064 and parameters: {'lambda_l1': 1.753591602430556e-06, 'lambda_l2': 9.644106110397196}. Best is trial 52 with value: 0.5269730738045824.
# regularization_factors, val_score: 0.526973: 100%|##########| 20/20 [02:44<00:00,  8.24s/it]
# min_data_in_leaf, val_score: 0.526973:  20%|##        | 1/5 [00:09<00:36,  9.02s/it][I 2023-07-12 09:53:09,365] Trial 63 finished with value: 0.5221797899898267 and parameters: {'min_child_samples': 50}. Best is trial 63 with value: 0.5221797899898267.
# min_data_in_leaf, val_score: 0.526973:  40%|####      | 2/5 [00:18<00:27,  9.04s/it][I 2023-07-12 09:53:18,409] Trial 64 finished with value: 0.5196274805854723 and parameters: {'min_child_samples': 100}. Best is trial 63 with value: 0.5221797899898267.
# min_data_in_leaf, val_score: 0.526973:  60%|######    | 3/5 [00:24<00:16,  8.03s/it][I 2023-07-12 09:53:25,248] Trial 65 finished with value: 0.5213636685250509 and parameters: {'min_child_samples': 10}. Best is trial 63 with value: 0.5221797899898267.
# min_data_in_leaf, val_score: 0.526973:  80%|########  | 4/5 [00:33<00:08,  8.37s/it][I 2023-07-12 09:53:34,148] Trial 66 finished with value: 0.5219876511077925 and parameters: {'min_child_samples': 25}. Best is trial 63 with value: 0.5221797899898267.
# min_data_in_leaf, val_score: 0.526973: 100%|##########| 5/5 [00:43<00:00,  8.85s/it][I 2023-07-12 09:53:43,841] Trial 67 finished with value: 0.5214923653233946 and parameters: {'min_child_samples': 5}. Best is trial 63 with value: 0.5221797899898267.
# min_data_in_leaf, val_score: 0.526973: 100%|##########| 5/5 [00:43<00:00,  8.70s/it]
# [I 2023-07-12 09:53:43,860] A new study created in memory with name: no-name-d45ccccb-0352-40b3-b9eb-b3868a5410e4
# feature_fraction, val_score: 0.510274:  14%|#4        | 1/7 [00:09<00:54,  9.15s/it][I 2023-07-12 09:53:53,030] Trial 0 finished with value: 0.5102736559993715 and parameters: {'feature_fraction': 0.7}. Best is trial 0 with value: 0.5102736559993715.
# feature_fraction, val_score: 0.510274:  29%|##8       | 2/7 [00:19<00:49,  9.83s/it][I 2023-07-12 09:54:03,340] Trial 1 finished with value: 0.5100746955069996 and parameters: {'feature_fraction': 0.8}. Best is trial 0 with value: 0.5102736559993715.
# feature_fraction, val_score: 0.512933:  43%|####2     | 3/7 [00:33<00:47, 11.87s/it][I 2023-07-12 09:54:17,628] Trial 2 finished with value: 0.5129326507794557 and parameters: {'feature_fraction': 1.0}. Best is trial 2 with value: 0.5129326507794557.
# feature_fraction, val_score: 0.512933:  57%|#####7    | 4/7 [00:43<00:33, 11.21s/it][I 2023-07-12 09:54:27,839] Trial 3 finished with value: 0.507626475084527 and parameters: {'feature_fraction': 0.4}. Best is trial 2 with value: 0.5129326507794557.
# feature_fraction, val_score: 0.512933:  71%|#######1  | 5/7 [00:55<00:22, 11.22s/it][I 2023-07-12 09:54:39,067] Trial 4 finished with value: 0.5070657852898126 and parameters: {'feature_fraction': 0.8999999999999999}. Best is trial 2 with value: 0.5129326507794557.
# feature_fraction, val_score: 0.512933:  86%|########5 | 6/7 [01:04<00:10, 10.70s/it][I 2023-07-12 09:54:48,748] Trial 5 finished with value: 0.5087313527669541 and parameters: {'feature_fraction': 0.6}. Best is trial 2 with value: 0.5129326507794557.
# feature_fraction, val_score: 0.512933: 100%|##########| 7/7 [01:12<00:00,  9.59s/it][I 2023-07-12 09:54:56,050] Trial 6 finished with value: 0.5055436093833594 and parameters: {'feature_fraction': 0.5}. Best is trial 2 with value: 0.5129326507794557.
# feature_fraction, val_score: 0.512933: 100%|##########| 7/7 [01:12<00:00, 10.31s/it]
# num_leaves, val_score: 0.513986:   5%|5         | 1/20 [00:09<02:58,  9.39s/it][I 2023-07-12 09:55:05,448] Trial 7 finished with value: 0.5139855849591618 and parameters: {'num_leaves': 6}. Best is trial 7 with value: 0.5139855849591618.
# num_leaves, val_score: 0.513986:  10%|#         | 2/20 [00:18<02:46,  9.23s/it][I 2023-07-12 09:55:14,569] Trial 8 finished with value: 0.5108012794728591 and parameters: {'num_leaves': 5}. Best is trial 7 with value: 0.5139855849591618.
# num_leaves, val_score: 0.513986:  15%|#5        | 3/20 [00:29<02:49,  9.96s/it][I 2023-07-12 09:55:25,407] Trial 9 finished with value: 0.5129326507794557 and parameters: {'num_leaves': 16}. Best is trial 7 with value: 0.5139855849591618.
# num_leaves, val_score: 0.514882:  20%|##        | 4/20 [00:35<02:18,  8.63s/it][I 2023-07-12 09:55:32,002] Trial 10 finished with value: 0.514881688515129 and parameters: {'num_leaves': 2}. Best is trial 10 with value: 0.514881688515129.
# num_leaves, val_score: 0.514882:  25%|##5       | 5/20 [00:44<02:07,  8.49s/it][I 2023-07-12 09:55:40,228] Trial 11 finished with value: 0.514881688515129 and parameters: {'num_leaves': 2}. Best is trial 10 with value: 0.514881688515129.
# num_leaves, val_score: 0.514882:  30%|###       | 6/20 [00:52<01:57,  8.42s/it][I 2023-07-12 09:55:48,531] Trial 12 finished with value: 0.514881688515129 and parameters: {'num_leaves': 2}. Best is trial 10 with value: 0.514881688515129.
# num_leaves, val_score: 0.514882:  35%|###5      | 7/20 [00:59<01:43,  7.98s/it][I 2023-07-12 09:55:55,595] Trial 13 finished with value: 0.5122060668135962 and parameters: {'num_leaves': 4}. Best is trial 10 with value: 0.514881688515129.
# num_leaves, val_score: 0.514882:  40%|####      | 8/20 [01:09<01:43,  8.62s/it][I 2023-07-12 09:56:05,571] Trial 14 finished with value: 0.5146621006390051 and parameters: {'num_leaves': 10}. Best is trial 10 with value: 0.514881688515129.
# num_leaves, val_score: 0.514882:  45%|####5     | 9/20 [01:17<01:33,  8.49s/it][I 2023-07-12 09:56:13,795] Trial 15 finished with value: 0.514881688515129 and parameters: {'num_leaves': 2}. Best is trial 10 with value: 0.514881688515129.
# num_leaves, val_score: 0.514882:  50%|#####     | 10/20 [01:25<01:22,  8.24s/it][I 2023-07-12 09:56:21,458] Trial 16 finished with value: 0.5129147737135372 and parameters: {'num_leaves': 9}. Best is trial 10 with value: 0.514881688515129.
# num_leaves, val_score: 0.514882:  55%|#####5    | 11/20 [01:34<01:17,  8.62s/it][I 2023-07-12 09:56:30,948] Trial 17 finished with value: 0.508909935904468 and parameters: {'num_leaves': 8}. Best is trial 10 with value: 0.514881688515129.
# num_leaves, val_score: 0.514882:  60%|######    | 12/20 [01:45<01:13,  9.20s/it][I 2023-07-12 09:56:41,475] Trial 18 finished with value: 0.5099411800776227 and parameters: {'num_leaves': 13}. Best is trial 10 with value: 0.514881688515129.
# num_leaves, val_score: 0.514882:  65%|######5   | 13/20 [01:51<00:58,  8.30s/it][I 2023-07-12 09:56:47,695] Trial 19 finished with value: 0.514881688515129 and parameters: {'num_leaves': 2}. Best is trial 10 with value: 0.514881688515129.
# num_leaves, val_score: 0.514882:  70%|#######   | 14/20 [02:00<00:51,  8.57s/it][I 2023-07-12 09:56:56,906] Trial 20 finished with value: 0.5139855849591618 and parameters: {'num_leaves': 6}. Best is trial 10 with value: 0.514881688515129.
# num_leaves, val_score: 0.514882:  75%|#######5  | 15/20 [02:09<00:42,  8.49s/it][I 2023-07-12 09:57:05,220] Trial 21 finished with value: 0.514881688515129 and parameters: {'num_leaves': 2}. Best is trial 10 with value: 0.514881688515129.
# num_leaves, val_score: 0.514882:  80%|########  | 16/20 [02:16<00:32,  8.02s/it][I 2023-07-12 09:57:12,141] Trial 22 finished with value: 0.5122060668135962 and parameters: {'num_leaves': 4}. Best is trial 10 with value: 0.514881688515129.
# num_leaves, val_score: 0.517926:  85%|########5 | 17/20 [02:24<00:24,  8.25s/it][I 2023-07-12 09:57:20,933] Trial 23 finished with value: 0.517925602777471 and parameters: {'num_leaves': 3}. Best is trial 23 with value: 0.517925602777471.
# num_leaves, val_score: 0.517926:  90%|######### | 18/20 [02:33<00:16,  8.49s/it][I 2023-07-12 09:57:29,975] Trial 24 finished with value: 0.5122060668135962 and parameters: {'num_leaves': 4}. Best is trial 23 with value: 0.517925602777471.
# num_leaves, val_score: 0.517926:  95%|#########5| 19/20 [02:40<00:08,  8.01s/it][I 2023-07-12 09:57:36,853] Trial 25 finished with value: 0.5122060668135962 and parameters: {'num_leaves': 4}. Best is trial 23 with value: 0.517925602777471.
# num_leaves, val_score: 0.517926: 100%|##########| 20/20 [02:50<00:00,  8.46s/it][I 2023-07-12 09:57:46,370] Trial 26 finished with value: 0.5103698546163241 and parameters: {'num_leaves': 7}. Best is trial 23 with value: 0.517925602777471.
# num_leaves, val_score: 0.517926: 100%|##########| 20/20 [02:50<00:00,  8.52s/it]
# bagging, val_score: 0.517926:  10%|#         | 1/10 [00:08<01:15,  8.40s/it][I 2023-07-12 09:57:54,795] Trial 27 finished with value: 0.5151189034282774 and parameters: {'bagging_fraction': 0.559008497627586, 'bagging_freq': 6}. Best is trial 27 with value: 0.5151189034282774.
# bagging, val_score: 0.517926:  20%|##        | 2/10 [00:16<01:06,  8.27s/it][I 2023-07-12 09:58:02,973] Trial 28 finished with value: 0.5142296131596708 and parameters: {'bagging_fraction': 0.5447262216809415, 'bagging_freq': 6}. Best is trial 27 with value: 0.5151189034282774.
# bagging, val_score: 0.517926:  30%|###       | 3/10 [00:25<01:00,  8.61s/it][I 2023-07-12 09:58:11,993] Trial 29 finished with value: 0.517734143151918 and parameters: {'bagging_fraction': 0.7854611407430475, 'bagging_freq': 7}. Best is trial 29 with value: 0.517734143151918.
# bagging, val_score: 0.517926:  40%|####      | 4/10 [00:34<00:52,  8.76s/it][I 2023-07-12 09:58:20,986] Trial 30 finished with value: 0.5163049154867959 and parameters: {'bagging_fraction': 0.8258928044452326, 'bagging_freq': 7}. Best is trial 29 with value: 0.517734143151918.
# bagging, val_score: 0.517926:  50%|#####     | 5/10 [00:41<00:40,  8.12s/it][I 2023-07-12 09:58:27,973] Trial 31 finished with value: 0.5161214567858499 and parameters: {'bagging_fraction': 0.8206223716403102, 'bagging_freq': 7}. Best is trial 29 with value: 0.517734143151918.
# bagging, val_score: 0.517926:  60%|######    | 6/10 [00:50<00:33,  8.43s/it][I 2023-07-12 09:58:37,003] Trial 32 finished with value: 0.5151879114030115 and parameters: {'bagging_fraction': 0.8601104395199844, 'bagging_freq': 7}. Best is trial 29 with value: 0.517734143151918.
# bagging, val_score: 0.517926:  70%|#######   | 7/10 [00:59<00:25,  8.61s/it][I 2023-07-12 09:58:45,977] Trial 33 finished with value: 0.5150252676074879 and parameters: {'bagging_fraction': 0.8257341283860348, 'bagging_freq': 7}. Best is trial 29 with value: 0.517734143151918.
# bagging, val_score: 0.517926:  80%|########  | 8/10 [01:06<00:15,  7.99s/it][I 2023-07-12 09:58:52,656] Trial 34 finished with value: 0.5116713175166305 and parameters: {'bagging_fraction': 0.7945838963512832, 'bagging_freq': 1}. Best is trial 29 with value: 0.517734143151918.
# bagging, val_score: 0.517926:  90%|######### | 9/10 [01:15<00:08,  8.42s/it][I 2023-07-12 09:59:02,029] Trial 35 finished with value: 0.5163861748773343 and parameters: {'bagging_fraction': 0.9810048756208192, 'bagging_freq': 5}. Best is trial 29 with value: 0.517734143151918.
# bagging, val_score: 0.517926: 100%|##########| 10/10 [01:25<00:00,  8.72s/it][I 2023-07-12 09:59:11,412] Trial 36 finished with value: 0.5176028154753634 and parameters: {'bagging_fraction': 0.99343927830051, 'bagging_freq': 4}. Best is trial 29 with value: 0.517734143151918.
# bagging, val_score: 0.517926: 100%|##########| 10/10 [01:25<00:00,  8.50s/it]
# feature_fraction_stage2, val_score: 0.519247:  33%|###3      | 1/3 [00:08<00:17,  8.53s/it][I 2023-07-12 09:59:19,954] Trial 37 finished with value: 0.5192470679892945 and parameters: {'feature_fraction': 0.9520000000000001}. Best is trial 37 with value: 0.5192470679892945.
# feature_fraction_stage2, val_score: 0.519247:  67%|######6   | 2/3 [00:15<00:07,  7.53s/it][I 2023-07-12 09:59:26,786] Trial 38 finished with value: 0.5180310524635003 and parameters: {'feature_fraction': 0.92}. Best is trial 37 with value: 0.5192470679892945.
# feature_fraction_stage2, val_score: 0.519247: 100%|##########| 3/3 [00:24<00:00,  8.12s/it][I 2023-07-12 09:59:35,601] Trial 39 finished with value: 0.5178788473742997 and parameters: {'feature_fraction': 0.9840000000000001}. Best is trial 37 with value: 0.5192470679892945.
# feature_fraction_stage2, val_score: 0.519247: 100%|##########| 3/3 [00:24<00:00,  8.06s/it]
# regularization_factors, val_score: 0.519247:   5%|5         | 1/20 [00:06<02:08,  6.75s/it][I 2023-07-12 09:59:42,373] Trial 40 finished with value: 0.519247005482071 and parameters: {'lambda_l1': 7.255370326809676e-08, 'lambda_l2': 0.00027180235432382806}. Best is trial 40 with value: 0.519247005482071.
# regularization_factors, val_score: 0.519247:  10%|#         | 2/20 [00:15<02:24,  8.03s/it][I 2023-07-12 09:59:51,285] Trial 41 finished with value: 0.5192469429748475 and parameters: {'lambda_l1': 1.7898956823406538e-08, 'lambda_l2': 0.0002214274164714948}. Best is trial 40 with value: 0.519247005482071.
# regularization_factors, val_score: 0.519247:  15%|#5        | 3/20 [00:24<02:22,  8.39s/it][I 2023-07-12 10:00:00,101] Trial 42 finished with value: 0.519247005482071 and parameters: {'lambda_l1': 3.654541143795018e-08, 'lambda_l2': 0.0002272833944096277}. Best is trial 40 with value: 0.519247005482071.
# regularization_factors, val_score: 0.519247:  20%|##        | 4/20 [00:31<02:04,  7.79s/it][I 2023-07-12 10:00:06,965] Trial 43 finished with value: 0.5192469429748475 and parameters: {'lambda_l1': 1.7324472307579463e-08, 'lambda_l2': 0.0002069201581657864}. Best is trial 40 with value: 0.519247005482071.
# regularization_factors, val_score: 0.519247:  25%|##5       | 5/20 [00:40<02:02,  8.18s/it][I 2023-07-12 10:00:15,844] Trial 44 finished with value: 0.519247005482071 and parameters: {'lambda_l1': 1.679935745872214e-08, 'lambda_l2': 0.0002540401669697502}. Best is trial 40 with value: 0.519247005482071.
# regularization_factors, val_score: 0.519247:  30%|###       | 6/20 [00:49<01:58,  8.44s/it][I 2023-07-12 10:00:24,788] Trial 45 finished with value: 0.5192469429748475 and parameters: {'lambda_l1': 2.102097373731163e-08, 'lambda_l2': 0.0002242769383478735}. Best is trial 40 with value: 0.519247005482071.
# regularization_factors, val_score: 0.519247:  35%|###5      | 7/20 [00:56<01:42,  7.92s/it][I 2023-07-12 10:00:31,641] Trial 46 finished with value: 0.519247005482071 and parameters: {'lambda_l1': 1.902221320962471e-08, 'lambda_l2': 0.00025512001202711613}. Best is trial 40 with value: 0.519247005482071.
# regularization_factors, val_score: 0.519247:  40%|####      | 8/20 [01:04<01:38,  8.24s/it][I 2023-07-12 10:00:40,583] Trial 47 finished with value: 0.519247255510965 and parameters: {'lambda_l1': 3.146527164817801e-08, 'lambda_l2': 0.0003252639246632538}. Best is trial 47 with value: 0.519247255510965.
# regularization_factors, val_score: 0.519247:  45%|####5     | 9/20 [01:13<01:33,  8.46s/it][I 2023-07-12 10:00:49,508] Trial 48 finished with value: 0.51805736800459 and parameters: {'lambda_l1': 3.3669263544229274e-06, 'lambda_l2': 0.01747188123823878}. Best is trial 47 with value: 0.519247255510965.
# regularization_factors, val_score: 0.519247:  50%|#####     | 10/20 [01:20<01:19,  7.95s/it][I 2023-07-12 10:00:56,316] Trial 49 finished with value: 0.5184650401161984 and parameters: {'lambda_l1': 0.1616914246098481, 'lambda_l2': 3.6133167456122286e-07}. Best is trial 47 with value: 0.519247255510965.
# regularization_factors, val_score: 0.519247:  55%|#####5    | 11/20 [01:29<01:14,  8.24s/it][I 2023-07-12 10:01:05,216] Trial 50 finished with value: 0.5189387198558133 and parameters: {'lambda_l1': 1.4896954287534481e-06, 'lambda_l2': 0.002622141476437662}. Best is trial 47 with value: 0.519247255510965.
# regularization_factors, val_score: 0.519247:  60%|######    | 12/20 [01:38<01:07,  8.43s/it][I 2023-07-12 10:01:14,072] Trial 51 finished with value: 0.5192466929459536 and parameters: {'lambda_l1': 1.809169282641604e-08, 'lambda_l2': 0.00013506540206840257}. Best is trial 47 with value: 0.519247255510965.
# regularization_factors, val_score: 0.519247:  65%|######5   | 13/20 [01:45<00:55,  7.93s/it][I 2023-07-12 10:01:20,854] Trial 52 finished with value: 0.519247005482071 and parameters: {'lambda_l1': 1.2438609976608635e-07, 'lambda_l2': 5.7886923644232524e-05}. Best is trial 47 with value: 0.519247255510965.
# regularization_factors, val_score: 0.519247:  70%|#######   | 14/20 [01:54<00:49,  8.24s/it][I 2023-07-12 10:01:29,803] Trial 53 finished with value: 0.5191510568940123 and parameters: {'lambda_l1': 6.192603082850888e-07, 'lambda_l2': 1.3505679664835981}. Best is trial 47 with value: 0.519247255510965.
# regularization_factors, val_score: 0.519247:  75%|#######5  | 15/20 [02:03<00:42,  8.47s/it][I 2023-07-12 10:01:38,806] Trial 54 finished with value: 0.5192470679892945 and parameters: {'lambda_l1': 1.0292861016122692e-08, 'lambda_l2': 1.7502384106561088e-05}. Best is trial 47 with value: 0.519247255510965.
# regularization_factors, val_score: 0.519247:  80%|########  | 16/20 [02:10<00:31,  7.99s/it][I 2023-07-12 10:01:45,686] Trial 55 finished with value: 0.5192470679892945 and parameters: {'lambda_l1': 2.731900310133487e-07, 'lambda_l2': 9.40724194066082e-06}. Best is trial 47 with value: 0.519247255510965.
# regularization_factors, val_score: 0.519247:  85%|########5 | 17/20 [02:18<00:24,  8.25s/it][I 2023-07-12 10:01:54,553] Trial 56 finished with value: 0.5192470679892945 and parameters: {'lambda_l1': 9.199005890806447e-07, 'lambda_l2': 8.369268534289236e-06}. Best is trial 47 with value: 0.519247255510965.
# regularization_factors, val_score: 0.519247:  90%|######### | 18/20 [02:27<00:16,  8.43s/it][I 2023-07-12 10:02:03,409] Trial 57 finished with value: 0.5192470679892945 and parameters: {'lambda_l1': 6.707316825297733e-07, 'lambda_l2': 3.656949686122421e-06}. Best is trial 47 with value: 0.519247255510965.
# regularization_factors, val_score: 0.519247:  95%|#########5| 19/20 [02:34<00:07,  7.90s/it][I 2023-07-12 10:02:10,072] Trial 58 finished with value: 0.5192470679892945 and parameters: {'lambda_l1': 6.4608575988856915e-06, 'lambda_l2': 3.771184986933584e-06}. Best is trial 47 with value: 0.519247255510965.
# regularization_factors, val_score: 0.519247: 100%|##########| 20/20 [02:45<00:00,  8.85s/it][I 2023-07-12 10:02:21,132] Trial 59 finished with value: 0.5192470679892945 and parameters: {'lambda_l1': 3.427547528260966e-07, 'lambda_l2': 5.274848929162121e-06}. Best is trial 47 with value: 0.519247255510965.
# regularization_factors, val_score: 0.519247: 100%|##########| 20/20 [02:45<00:00,  8.28s/it]
# min_data_in_leaf, val_score: 0.519247:  20%|##        | 1/5 [00:08<00:35,  8.93s/it][I 2023-07-12 10:02:30,081] Trial 60 finished with value: 0.517935291397112 and parameters: {'min_child_samples': 50}. Best is trial 60 with value: 0.517935291397112.
# min_data_in_leaf, val_score: 0.519247:  40%|####      | 2/5 [00:15<00:23,  7.68s/it][I 2023-07-12 10:02:36,880] Trial 61 finished with value: 0.5156990329694975 and parameters: {'min_child_samples': 100}. Best is trial 60 with value: 0.517935291397112.
# min_data_in_leaf, val_score: 0.519247:  60%|######    | 3/5 [00:24<00:16,  8.22s/it][I 2023-07-12 10:02:45,743] Trial 62 finished with value: 0.5176998266862214 and parameters: {'min_child_samples': 10}. Best is trial 60 with value: 0.517935291397112.
# min_data_in_leaf, val_score: 0.519247:  80%|########  | 4/5 [00:33<00:08,  8.46s/it][I 2023-07-12 10:02:54,563] Trial 63 finished with value: 0.5142082981964603 and parameters: {'min_child_samples': 5}. Best is trial 60 with value: 0.517935291397112.
# min_data_in_leaf, val_score: 0.519604: 100%|##########| 5/5 [00:40<00:00,  7.84s/it][I 2023-07-12 10:03:01,316] Trial 64 finished with value: 0.5196036091920873 and parameters: {'min_child_samples': 25}. Best is trial 64 with value: 0.5196036091920873.
# min_data_in_leaf, val_score: 0.519604: 100%|##########| 5/5 [00:40<00:00,  8.04s/it]
# [I 2023-07-12 10:03:01,339] A new study created in memory with name: no-name-155e25c5-c349-4ddf-9950-5f42b159dfec
# feature_fraction, val_score: 0.513026:  14%|#4        | 1/7 [00:10<01:02, 10.46s/it][I 2023-07-12 10:03:11,818] Trial 0 finished with value: 0.5130257473505144 and parameters: {'feature_fraction': 0.5}. Best is trial 0 with value: 0.5130257473505144.
# feature_fraction, val_score: 0.513859:  29%|##8       | 2/7 [00:21<00:53, 10.79s/it][I 2023-07-12 10:03:22,834] Trial 1 finished with value: 0.5138594852606735 and parameters: {'feature_fraction': 1.0}. Best is trial 1 with value: 0.5138594852606735.
# feature_fraction, val_score: 0.514031:  43%|####2     | 3/7 [00:31<00:41, 10.31s/it][I 2023-07-12 10:03:32,581] Trial 2 finished with value: 0.5140313248494496 and parameters: {'feature_fraction': 0.6}. Best is trial 2 with value: 0.5140313248494496.
# feature_fraction, val_score: 0.515650:  57%|#####7    | 4/7 [00:41<00:30, 10.17s/it][I 2023-07-12 10:03:42,523] Trial 3 finished with value: 0.5156503202615765 and parameters: {'feature_fraction': 0.7}. Best is trial 3 with value: 0.5156503202615765.
# feature_fraction, val_score: 0.515650:  71%|#######1  | 5/7 [00:48<00:18,  9.28s/it][I 2023-07-12 10:03:50,219] Trial 4 finished with value: 0.5145036804136461 and parameters: {'feature_fraction': 0.4}. Best is trial 3 with value: 0.5156503202615765.
# feature_fraction, val_score: 0.515650:  86%|########5 | 6/7 [00:59<00:09,  9.77s/it][I 2023-07-12 10:04:00,943] Trial 5 finished with value: 0.5140778660413132 and parameters: {'feature_fraction': 0.8999999999999999}. Best is trial 3 with value: 0.5156503202615765.
# feature_fraction, val_score: 0.515650: 100%|##########| 7/7 [01:09<00:00,  9.96s/it][I 2023-07-12 10:04:11,307] Trial 6 finished with value: 0.512591425448486 and parameters: {'feature_fraction': 0.8}. Best is trial 3 with value: 0.5156503202615765.
# feature_fraction, val_score: 0.515650: 100%|##########| 7/7 [01:09<00:00, 10.00s/it]
# num_leaves, val_score: 0.517859:   5%|5         | 1/20 [00:08<02:43,  8.61s/it][I 2023-07-12 10:04:19,932] Trial 7 finished with value: 0.517859087658771 and parameters: {'num_leaves': 6}. Best is trial 7 with value: 0.517859087658771.
# num_leaves, val_score: 0.517859:  10%|#         | 2/20 [00:15<02:18,  7.72s/it][I 2023-07-12 10:04:27,030] Trial 8 finished with value: 0.5118606536697886 and parameters: {'num_leaves': 9}. Best is trial 7 with value: 0.517859087658771.
# num_leaves, val_score: 0.517859:  15%|#5        | 3/20 [00:24<02:19,  8.20s/it][I 2023-07-12 10:04:35,797] Trial 9 finished with value: 0.517859087658771 and parameters: {'num_leaves': 6}. Best is trial 7 with value: 0.517859087658771.
# num_leaves, val_score: 0.520236:  20%|##        | 4/20 [00:31<02:05,  7.84s/it][I 2023-07-12 10:04:43,104] Trial 10 finished with value: 0.5202364417657402 and parameters: {'num_leaves': 2}. Best is trial 10 with value: 0.5202364417657402.
# num_leaves, val_score: 0.520236:  25%|##5       | 5/20 [00:38<01:49,  7.27s/it][I 2023-07-12 10:04:49,355] Trial 11 finished with value: 0.5202364417657402 and parameters: {'num_leaves': 2}. Best is trial 10 with value: 0.5202364417657402.
# num_leaves, val_score: 0.520236:  30%|###       | 6/20 [00:45<01:44,  7.46s/it][I 2023-07-12 10:04:57,178] Trial 12 finished with value: 0.5202364417657402 and parameters: {'num_leaves': 2}. Best is trial 10 with value: 0.5202364417657402.
# num_leaves, val_score: 0.520236:  35%|###5      | 7/20 [00:51<01:30,  6.93s/it][I 2023-07-12 10:05:03,020] Trial 13 finished with value: 0.5202364417657402 and parameters: {'num_leaves': 2}. Best is trial 10 with value: 0.5202364417657402.
# num_leaves, val_score: 0.520236:  40%|####      | 8/20 [01:01<01:35,  7.93s/it][I 2023-07-12 10:05:13,081] Trial 14 finished with value: 0.5199283565911054 and parameters: {'num_leaves': 15}. Best is trial 10 with value: 0.5202364417657402.
# num_leaves, val_score: 0.520236:  45%|####5     | 9/20 [01:07<01:19,  7.26s/it][I 2023-07-12 10:05:18,867] Trial 15 finished with value: 0.5202364417657402 and parameters: {'num_leaves': 2}. Best is trial 10 with value: 0.5202364417657402.
# num_leaves, val_score: 0.520236:  50%|#####     | 10/20 [01:16<01:16,  7.64s/it][I 2023-07-12 10:05:27,351] Trial 16 finished with value: 0.517859087658771 and parameters: {'num_leaves': 6}. Best is trial 10 with value: 0.5202364417657402.
# num_leaves, val_score: 0.520236:  55%|#####5    | 11/20 [01:26<01:15,  8.39s/it][I 2023-07-12 10:05:37,435] Trial 17 finished with value: 0.5156503202615765 and parameters: {'num_leaves': 16}. Best is trial 10 with value: 0.5202364417657402.
# num_leaves, val_score: 0.520236:  60%|######    | 12/20 [01:34<01:06,  8.31s/it][I 2023-07-12 10:05:45,576] Trial 18 finished with value: 0.5153638166880075 and parameters: {'num_leaves': 4}. Best is trial 10 with value: 0.5202364417657402.
# num_leaves, val_score: 0.520236:  65%|######5   | 13/20 [01:42<00:57,  8.17s/it][I 2023-07-12 10:05:53,416] Trial 19 finished with value: 0.5163073392644577 and parameters: {'num_leaves': 12}. Best is trial 10 with value: 0.5202364417657402.
# num_leaves, val_score: 0.520236:  70%|#######   | 14/20 [01:51<00:50,  8.48s/it][I 2023-07-12 10:06:02,602] Trial 20 finished with value: 0.5118606536697886 and parameters: {'num_leaves': 9}. Best is trial 10 with value: 0.5202364417657402.
# num_leaves, val_score: 0.520236:  75%|#######5  | 15/20 [01:57<00:38,  7.65s/it][I 2023-07-12 10:06:08,337] Trial 21 finished with value: 0.5202364417657402 and parameters: {'num_leaves': 2}. Best is trial 10 with value: 0.5202364417657402.
# num_leaves, val_score: 0.520236:  80%|########  | 16/20 [02:05<00:31,  7.88s/it][I 2023-07-12 10:06:16,744] Trial 22 finished with value: 0.5153638166880075 and parameters: {'num_leaves': 4}. Best is trial 10 with value: 0.5202364417657402.
# num_leaves, val_score: 0.520236:  85%|########5 | 17/20 [02:13<00:24,  8.05s/it][I 2023-07-12 10:06:25,177] Trial 23 finished with value: 0.5153638166880075 and parameters: {'num_leaves': 4}. Best is trial 10 with value: 0.5202364417657402.
# num_leaves, val_score: 0.520236:  90%|######### | 18/20 [02:20<00:15,  7.52s/it][I 2023-07-12 10:06:31,486] Trial 24 finished with value: 0.5153638166880075 and parameters: {'num_leaves': 4}. Best is trial 10 with value: 0.5202364417657402.
# num_leaves, val_score: 0.520236:  95%|#########5| 19/20 [02:29<00:08,  8.19s/it][I 2023-07-12 10:06:41,219] Trial 25 finished with value: 0.5202364417657402 and parameters: {'num_leaves': 2}. Best is trial 10 with value: 0.5202364417657402.
# num_leaves, val_score: 0.520236: 100%|##########| 20/20 [02:36<00:00,  7.69s/it][I 2023-07-12 10:06:47,741] Trial 26 finished with value: 0.513385127924784 and parameters: {'num_leaves': 5}. Best is trial 10 with value: 0.5202364417657402.
# num_leaves, val_score: 0.520236: 100%|##########| 20/20 [02:36<00:00,  7.82s/it]
# bagging, val_score: 0.520236:  10%|#         | 1/10 [00:08<01:14,  8.23s/it][I 2023-07-12 10:06:55,988] Trial 27 finished with value: 0.5195639715876033 and parameters: {'bagging_fraction': 0.7017008803595175, 'bagging_freq': 2}. Best is trial 27 with value: 0.5195639715876033.
# bagging, val_score: 0.520236:  20%|##        | 2/10 [00:16<01:06,  8.25s/it][I 2023-07-12 10:07:04,252] Trial 28 finished with value: 0.5195610314854291 and parameters: {'bagging_fraction': 0.9491892983407317, 'bagging_freq': 7}. Best is trial 27 with value: 0.5195639715876033.
# bagging, val_score: 0.520236:  30%|###       | 3/10 [00:21<00:48,  6.91s/it][I 2023-07-12 10:07:09,573] Trial 29 finished with value: 0.5199019582269032 and parameters: {'bagging_fraction': 0.402336529224791, 'bagging_freq': 6}. Best is trial 29 with value: 0.5199019582269032.
# bagging, val_score: 0.520236:  40%|####      | 4/10 [00:29<00:44,  7.41s/it][I 2023-07-12 10:07:17,747] Trial 30 finished with value: 0.518846711767834 and parameters: {'bagging_fraction': 0.4128324037377869, 'bagging_freq': 1}. Best is trial 29 with value: 0.5199019582269032.
# bagging, val_score: 0.520236:  50%|#####     | 5/10 [00:36<00:35,  7.03s/it][I 2023-07-12 10:07:24,103] Trial 31 finished with value: 0.5196060713485229 and parameters: {'bagging_fraction': 0.9960347746633027, 'bagging_freq': 4}. Best is trial 29 with value: 0.5199019582269032.
# bagging, val_score: 0.520951:  60%|######    | 6/10 [00:44<00:29,  7.32s/it][I 2023-07-12 10:07:31,989] Trial 32 finished with value: 0.5209507614833353 and parameters: {'bagging_fraction': 0.6756493547347938, 'bagging_freq': 4}. Best is trial 32 with value: 0.5209507614833353.
# bagging, val_score: 0.521465:  70%|#######   | 7/10 [00:50<00:20,  6.87s/it][I 2023-07-12 10:07:37,927] Trial 33 finished with value: 0.5214645912547975 and parameters: {'bagging_fraction': 0.684274999246931, 'bagging_freq': 4}. Best is trial 33 with value: 0.5214645912547975.
# bagging, val_score: 0.522787:  80%|########  | 8/10 [00:58<00:14,  7.21s/it][I 2023-07-12 10:07:45,876] Trial 34 finished with value: 0.52278707423489 and parameters: {'bagging_fraction': 0.6785191691384586, 'bagging_freq': 4}. Best is trial 34 with value: 0.52278707423489.
# bagging, val_score: 0.522787:  90%|######### | 9/10 [01:04<00:06,  6.80s/it][I 2023-07-12 10:07:51,782] Trial 35 finished with value: 0.5209564540215875 and parameters: {'bagging_fraction': 0.6600883809403458, 'bagging_freq': 4}. Best is trial 34 with value: 0.52278707423489.
# bagging, val_score: 0.522787: 100%|##########| 10/10 [01:11<00:00,  7.08s/it][I 2023-07-12 10:07:59,482] Trial 36 finished with value: 0.5221789109723926 and parameters: {'bagging_fraction': 0.6705142704984436, 'bagging_freq': 4}. Best is trial 34 with value: 0.52278707423489.
# bagging, val_score: 0.522787: 100%|##########| 10/10 [01:11<00:00,  7.17s/it]
# feature_fraction_stage2, val_score: 0.522787:  17%|#6        | 1/6 [00:08<00:40,  8.05s/it][I 2023-07-12 10:08:07,551] Trial 37 finished with value: 0.5218444899889209 and parameters: {'feature_fraction': 0.748}. Best is trial 37 with value: 0.5218444899889209.
# feature_fraction_stage2, val_score: 0.522787:  33%|###3      | 2/6 [00:13<00:26,  6.64s/it][I 2023-07-12 10:08:13,210] Trial 38 finished with value: 0.5213252179006682 and parameters: {'feature_fraction': 0.62}. Best is trial 37 with value: 0.5218444899889209.
# ...
# num_leaves, val_score: 0.514321:  30%|###       | 6/20 [00:46<01:47,  7.65s/it][I 2023-07-12 10:22:09,702] Trial 12 finished with value: 0.5143211662509042 and parameters: {'num_leaves': 2}. Best is trial 10 with value: 0.5143211662509042.
# num_leaves, val_score: 0.514321:  35%|###5      | 7/20 [00:52<01:31,  7.05s/it][I 2023-07-12 10:22:15,494] Trial 13 finished with value: 0.5143211662509042 and parameters: {'num_leaves': 2}. Best is trial 10 with value: 0.5143211662509042.
# num_leaves, val_score: 0.514321:  40%|####      | 8/20 [01:00<01:27,  7.29s/it][I 2023-07-12 10:22:23,313] Trial 14 finished with value: 0.5143211662509042 and parameters: {'num_leaves': 2}. Best is trial 10 with value: 0.5143211662509042.
# num_leaves, val_score: 0.514321:  45%|####5     | 9/20 [01:10<01:28,  8.00s/it][I 2023-07-12 10:22:32,870] Trial 15 finished with value: 0.505307558119513 and parameters: {'num_leaves': 12}. Best is trial 10 with value: 0.5143211662509042.
# num_leaves, val_score: 0.514321:  50%|#####     | 10/20 [01:17<01:19,  7.91s/it][I 2023-07-12 10:22:40,585] Trial 16 finished with value: 0.5098866438011342 and parameters: {'num_leaves': 5}. Best is trial 10 with value: 0.5143211662509042.
# num_leaves, val_score: 0.514321:  55%|#####5    | 11/20 [01:29<01:21,  9.07s/it][I 2023-07-12 10:22:52,286] Trial 17 finished with value: 0.5035340491411238 and parameters: {'num_leaves': 10}. Best is trial 10 with value: 0.5143211662509042.
# num_leaves, val_score: 0.514321:  60%|######    | 12/20 [01:38<01:11,  9.00s/it][I 2023-07-12 10:23:01,113] Trial 18 finished with value: 0.5091343899928493 and parameters: {'num_leaves': 4}. Best is trial 10 with value: 0.5143211662509042.
# num_leaves, val_score: 0.514321:  65%|######5   | 13/20 [01:47<01:03,  9.11s/it][I 2023-07-12 10:23:10,478] Trial 19 finished with value: 0.5091725151858582 and parameters: {'num_leaves': 8}. Best is trial 10 with value: 0.5143211662509042.
# num_leaves, val_score: 0.514321:  70%|#######   | 14/20 [01:54<00:50,  8.37s/it][I 2023-07-12 10:23:17,131] Trial 20 finished with value: 0.5091343899928493 and parameters: {'num_leaves': 4}. Best is trial 10 with value: 0.5143211662509042.
# num_leaves, val_score: 0.514321:  75%|#######5  | 15/20 [02:02<00:41,  8.33s/it][I 2023-07-12 10:23:25,391] Trial 21 finished with value: 0.5143211662509042 and parameters: {'num_leaves': 2}. Best is trial 10 with value: 0.5143211662509042.
# num_leaves, val_score: 0.514321:  80%|########  | 16/20 [02:13<00:36,  9.17s/it][I 2023-07-12 10:23:36,502] Trial 22 finished with value: 0.5091343899928493 and parameters: {'num_leaves': 4}. Best is trial 10 with value: 0.5143211662509042.
# num_leaves, val_score: 0.514321:  85%|########5 | 17/20 [02:19<00:24,  8.24s/it][I 2023-07-12 10:23:42,586] Trial 23 finished with value: 0.5143211662509042 and parameters: {'num_leaves': 2}. Best is trial 10 with value: 0.5143211662509042.
# num_leaves, val_score: 0.514321:  90%|######### | 18/20 [02:28<00:17,  8.50s/it][I 2023-07-12 10:23:51,693] Trial 24 finished with value: 0.5091343899928493 and parameters: {'num_leaves': 4}. Best is trial 10 with value: 0.5143211662509042.
# num_leaves, val_score: 0.514321:  95%|#########5| 19/20 [02:39<00:08,  8.98s/it][I 2023-07-12 10:24:01,768] Trial 25 finished with value: 0.5072426929161329 and parameters: {'num_leaves': 11}. Best is trial 10 with value: 0.5143211662509042.
# num_leaves, val_score: 0.514321: 100%|##########| 20/20 [02:45<00:00,  8.36s/it][I 2023-07-12 10:24:08,682] Trial 26 finished with value: 0.5078676960802114 and parameters: {'num_leaves': 6}. Best is trial 10 with value: 0.5143211662509042.
# num_leaves, val_score: 0.514321: 100%|##########| 20/20 [02:45<00:00,  8.30s/it]
# bagging, val_score: 0.516193:  10%|#         | 1/10 [00:08<01:13,  8.12s/it][I 2023-07-12 10:24:16,838] Trial 27 finished with value: 0.5161929257266865 and parameters: {'bagging_fraction': 0.5238240132910134, 'bagging_freq': 4}. Best is trial 27 with value: 0.5161929257266865.
# bagging, val_score: 0.516369:  20%|##        | 2/10 [00:16<01:04,  8.10s/it][I 2023-07-12 10:24:24,913] Trial 28 finished with value: 0.5163691141186402 and parameters: {'bagging_fraction': 0.5046765283213122, 'bagging_freq': 4}. Best is trial 28 with value: 0.5163691141186402.
# bagging, val_score: 0.517520:  30%|###       | 3/10 [00:22<00:49,  7.06s/it][I 2023-07-12 10:24:30,737] Trial 29 finished with value: 0.5175203074465564 and parameters: {'bagging_fraction': 0.5000366978403166, 'bagging_freq': 4}. Best is trial 29 with value: 0.5175203074465564.
# bagging, val_score: 0.517520:  40%|####      | 4/10 [00:30<00:44,  7.44s/it][I 2023-07-12 10:24:38,767] Trial 30 finished with value: 0.5154650470418006 and parameters: {'bagging_fraction': 0.4948389748536938, 'bagging_freq': 4}. Best is trial 29 with value: 0.5175203074465564.
# bagging, val_score: 0.517520:  50%|#####     | 5/10 [00:36<00:34,  6.94s/it][I 2023-07-12 10:24:44,799] Trial 31 finished with value: 0.5170904302703032 and parameters: {'bagging_fraction': 0.5023249602605905, 'bagging_freq': 4}. Best is trial 29 with value: 0.5175203074465564.
# bagging, val_score: 0.517520:  60%|######    | 6/10 [00:44<00:29,  7.39s/it][I 2023-07-12 10:24:53,058] Trial 32 finished with value: 0.5174678071807739 and parameters: {'bagging_fraction': 0.5045836367741349, 'bagging_freq': 4}. Best is trial 29 with value: 0.5175203074465564.
# bagging, val_score: 0.517520:  70%|#######   | 7/10 [00:50<00:20,  6.88s/it][I 2023-07-12 10:24:58,906] Trial 33 finished with value: 0.517193055789845 and parameters: {'bagging_fraction': 0.49190721239936963, 'bagging_freq': 4}. Best is trial 29 with value: 0.5175203074465564.
# bagging, val_score: 0.517520:  80%|########  | 8/10 [00:58<00:14,  7.29s/it][I 2023-07-12 10:25:07,067] Trial 34 finished with value: 0.5164624270910372 and parameters: {'bagging_fraction': 0.48392251698840344, 'bagging_freq': 4}. Best is trial 29 with value: 0.5175203074465564.
# bagging, val_score: 0.517520:  90%|######### | 9/10 [01:06<00:07,  7.66s/it][I 2023-07-12 10:25:15,533] Trial 35 finished with value: 0.5148584814710625 and parameters: {'bagging_fraction': 0.7766527039039994, 'bagging_freq': 5}. Best is trial 29 with value: 0.5175203074465564.
# bagging, val_score: 0.517520: 100%|##########| 10/10 [01:13<00:00,  7.23s/it][I 2023-07-12 10:25:21,816] Trial 36 finished with value: 0.515851423997834 and parameters: {'bagging_fraction': 0.598585053404174, 'bagging_freq': 1}. Best is trial 29 with value: 0.5175203074465564.
# bagging, val_score: 0.517520: 100%|##########| 10/10 [01:13<00:00,  7.31s/it]
# feature_fraction_stage2, val_score: 0.517520:  17%|#6        | 1/6 [00:08<00:40,  8.13s/it][I 2023-07-12 10:25:29,963] Trial 37 finished with value: 0.5166103028396581 and parameters: {'feature_fraction': 0.6799999999999999}. Best is trial 37 with value: 0.5166103028396581.
# feature_fraction_stage2, val_score: 0.518296:  33%|###3      | 2/6 [00:13<00:26,  6.70s/it][I 2023-07-12 10:25:35,661] Trial 38 finished with value: 0.5182960613738107 and parameters: {'feature_fraction': 0.552}. Best is trial 38 with value: 0.5182960613738107.
# feature_fraction_stage2, val_score: 0.518296:  50%|#####     | 3/6 [00:21<00:21,  7.26s/it][I 2023-07-12 10:25:43,585] Trial 39 finished with value: 0.5176209954562895 and parameters: {'feature_fraction': 0.6479999999999999}. Best is trial 38 with value: 0.5182960613738107.
# feature_fraction_stage2, val_score: 0.518296:  67%|######6   | 4/6 [00:27<00:13,  6.64s/it][I 2023-07-12 10:25:49,275] Trial 40 finished with value: 0.5166859282225116 and parameters: {'feature_fraction': 0.584}. Best is trial 38 with value: 0.5182960613738107.
# feature_fraction_stage2, val_score: 0.518941:  83%|########3 | 5/6 [00:35<00:07,  7.30s/it][I 2023-07-12 10:25:57,751] Trial 41 finished with value: 0.5189411271394562 and parameters: {'feature_fraction': 0.52}. Best is trial 41 with value: 0.5189411271394562.
# feature_fraction_stage2, val_score: 0.518941: 100%|##########| 6/6 [00:44<00:00,  7.65s/it][I 2023-07-12 10:26:06,086] Trial 42 finished with value: 0.5175203074465564 and parameters: {'feature_fraction': 0.616}. Best is trial 41 with value: 0.5189411271394562.
# feature_fraction_stage2, val_score: 0.518941: 100%|##########| 6/6 [00:44<00:00,  7.38s/it]
# regularization_factors, val_score: 0.518941:   5%|5         | 1/20 [00:06<02:03,  6.48s/it][I 2023-07-12 10:26:12,584] Trial 43 finished with value: 0.5189411896397725 and parameters: {'lambda_l1': 0.001110948031106268, 'lambda_l2': 2.3229065516626605e-07}. Best is trial 43 with value: 0.5189411896397725.
# regularization_factors, val_score: 0.519022:  10%|#         | 2/20 [00:15<02:18,  7.72s/it][I 2023-07-12 10:26:21,181] Trial 44 finished with value: 0.5190224400511028 and parameters: {'lambda_l1': 0.00201091397745577, 'lambda_l2': 1.0186781485223825e-07}. Best is trial 44 with value: 0.5190224400511028.
# regularization_factors, val_score: 0.519022:  15%|#5        | 3/20 [00:23<02:18,  8.15s/it][I 2023-07-12 10:26:29,834] Trial 45 finished with value: 0.5190224400511028 and parameters: {'lambda_l1': 0.002056311440580699, 'lambda_l2': 6.670178583650926e-08}. Best is trial 44 with value: 0.5190224400511028.
# regularization_factors, val_score: 0.519023:  20%|##        | 4/20 [00:29<01:58,  7.38s/it][I 2023-07-12 10:26:36,038] Trial 46 finished with value: 0.5190226900523683 and parameters: {'lambda_l1': 0.0017394098442216192, 'lambda_l2': 7.978986790449156e-08}. Best is trial 46 with value: 0.5190226900523683.
# regularization_factors, val_score: 0.519023:  25%|##5       | 5/20 [00:38<01:56,  7.77s/it][I 2023-07-12 10:26:44,488] Trial 47 finished with value: 0.5190234400561653 and parameters: {'lambda_l1': 0.0030869305582100935, 'lambda_l2': 1.1877793820540171e-07}. Best is trial 47 with value: 0.5190234400561653.
# regularization_factors, val_score: 0.519023:  30%|###       | 6/20 [00:44<01:38,  7.07s/it][I 2023-07-12 10:26:50,205] Trial 48 finished with value: 0.5190225650517356 and parameters: {'lambda_l1': 0.0020889633354931165, 'lambda_l2': 5.717243614002566e-08}. Best is trial 47 with value: 0.5190234400561653.
# regularization_factors, val_score: 0.519023:  35%|###5      | 7/20 [00:52<01:35,  7.34s/it][I 2023-07-12 10:26:58,107] Trial 49 finished with value: 0.519022627552052 and parameters: {'lambda_l1': 0.002115942107821807, 'lambda_l2': 6.479180801426059e-08}. Best is trial 47 with value: 0.5190234400561653.
# regularization_factors, val_score: 0.519023:  40%|####      | 8/20 [00:58<01:23,  6.99s/it][I 2023-07-12 10:27:04,346] Trial 50 finished with value: 0.5190227525526848 and parameters: {'lambda_l1': 0.0022531352415498373, 'lambda_l2': 6.366123586888683e-08}. Best is trial 47 with value: 0.5190234400561653.
# regularization_factors, val_score: 0.519023:  45%|####5     | 9/20 [01:06<01:19,  7.27s/it][I 2023-07-12 10:27:12,251] Trial 51 finished with value: 0.519022940053634 and parameters: {'lambda_l1': 0.0023862720506241477, 'lambda_l2': 6.246173399822914e-08}. Best is trial 47 with value: 0.5190234400561653.
# regularization_factors, val_score: 0.519023:  50%|#####     | 10/20 [01:14<01:15,  7.60s/it][I 2023-07-12 10:27:20,560] Trial 52 finished with value: 0.5190231900548996 and parameters: {'lambda_l1': 0.003210359132708789, 'lambda_l2': 6.724114078410134e-08}. Best is trial 47 with value: 0.5190234400561653.
# regularization_factors, val_score: 0.519024:  55%|#####5    | 11/20 [01:20<01:04,  7.14s/it][I 2023-07-12 10:27:26,668] Trial 53 finished with value: 0.5190235025564817 and parameters: {'lambda_l1': 0.0030764566092267654, 'lambda_l2': 5.568363329128551e-08}. Best is trial 53 with value: 0.5190235025564817.
# regularization_factors, val_score: 0.519024:  60%|######    | 12/20 [01:28<00:59,  7.49s/it][I 2023-07-12 10:27:34,961] Trial 54 finished with value: 0.5190224400511028 and parameters: {'lambda_l1': 0.005762511048855434, 'lambda_l2': 4.227927367650259e-08}. Best is trial 53 with value: 0.5190235025564817.
# regularization_factors, val_score: 0.519024:  65%|######5   | 13/20 [01:39<00:58,  8.43s/it][I 2023-07-12 10:27:45,543] Trial 55 finished with value: 0.5173731192014159 and parameters: {'lambda_l1': 0.034968671187491134, 'lambda_l2': 0.0008411042887951452}. Best is trial 53 with value: 0.5190235025564817.
# regularization_factors, val_score: 0.519024:  70%|#######   | 14/20 [01:45<00:46,  7.72s/it][I 2023-07-12 10:27:51,634] Trial 56 finished with value: 0.5189411271394562 and parameters: {'lambda_l1': 1.5209323724730644e-05, 'lambda_l2': 2.255444298929114e-06}. Best is trial 53 with value: 0.5190235025564817.
# regularization_factors, val_score: 0.519024:  75%|#######5  | 15/20 [01:53<00:38,  7.79s/it][I 2023-07-12 10:27:59,585] Trial 57 finished with value: 0.5177374960460738 and parameters: {'lambda_l1': 0.2572190072669636, 'lambda_l2': 1.129236520030089e-08}. Best is trial 53 with value: 0.5190235025564817.
# regularization_factors, val_score: 0.519024:  80%|########  | 16/20 [01:59<00:28,  7.17s/it][I 2023-07-12 10:28:05,319] Trial 58 finished with value: 0.5189413146404054 and parameters: {'lambda_l1': 0.0001504279631793389, 'lambda_l2': 3.84206835067594e-06}. Best is trial 53 with value: 0.5190235025564817.
# regularization_factors, val_score: 0.519024:  85%|########5 | 17/20 [02:07<00:22,  7.50s/it][I 2023-07-12 10:28:13,587] Trial 59 finished with value: 0.5173738067048964 and parameters: {'lambda_l1': 0.037076526435728924, 'lambda_l2': 2.44355359347621e-06}. Best is trial 53 with value: 0.5190235025564817.
# regularization_factors, val_score: 0.519024:  90%|######### | 18/20 [02:13<00:14,  7.08s/it][I 2023-07-12 10:28:19,677] Trial 60 finished with value: 0.5189413146404054 and parameters: {'lambda_l1': 0.00017412165765127606, 'lambda_l2': 1.3286638038633493e-08}. Best is trial 53 with value: 0.5190235025564817.
# regularization_factors, val_score: 0.519024:  95%|#########5| 19/20 [02:21<00:07,  7.47s/it][I 2023-07-12 10:28:28,062] Trial 61 finished with value: 0.5190223150504699 and parameters: {'lambda_l1': 0.0057401478251817815, 'lambda_l2': 3.198049609422825e-07}. Best is trial 53 with value: 0.5190235025564817.
# regularization_factors, val_score: 0.519024: 100%|##########| 20/20 [02:29<00:00,  7.60s/it][I 2023-07-12 10:28:35,955] Trial 62 finished with value: 0.5189411896397725 and parameters: {'lambda_l1': 0.000729780079525455, 'lambda_l2': 2.747822562913104e-07}. Best is trial 53 with value: 0.5190235025564817.
# regularization_factors, val_score: 0.519024: 100%|##########| 20/20 [02:29<00:00,  7.49s/it]
# min_data_in_leaf, val_score: 0.519024:  20%|##        | 1/5 [00:06<00:24,  6.24s/it][I 2023-07-12 10:28:42,210] Trial 63 finished with value: 0.5190235025564817 and parameters: {'min_child_samples': 25}. Best is trial 63 with value: 0.5190235025564817.
# min_data_in_leaf, val_score: 0.519024:  40%|####      | 2/5 [00:14<00:21,  7.26s/it][I 2023-07-12 10:28:50,179] Trial 64 finished with value: 0.5177950588374853 and parameters: {'min_child_samples': 5}. Best is trial 63 with value: 0.5190235025564817.
# min_data_in_leaf, val_score: 0.519024:  60%|######    | 3/5 [00:20<00:13,  6.80s/it][I 2023-07-12 10:28:56,456] Trial 65 finished with value: 0.5190235025564817 and parameters: {'min_child_samples': 50}. Best is trial 63 with value: 0.5190235025564817.
# min_data_in_leaf, val_score: 0.519024:  80%|########  | 4/5 [00:28<00:07,  7.42s/it][I 2023-07-12 10:29:04,805] Trial 66 finished with value: 0.517613557918637 and parameters: {'min_child_samples': 100}. Best is trial 63 with value: 0.5190235025564817.
# min_data_in_leaf, val_score: 0.519024: 100%|##########| 5/5 [00:37<00:00,  7.76s/it][I 2023-07-12 10:29:13,169] Trial 67 finished with value: 0.5177950588374853 and parameters: {'min_child_samples': 10}. Best is trial 63 with value: 0.5190235025564817.
# min_data_in_leaf, val_score: 0.519024: 100%|##########| 5/5 [00:37<00:00,  7.44s/it]

# %%
i = 0
result = []
kf = KFold(n_splits=5, shuffle=False)
for learn_index, valid_index in kf.split(X_train, Y_train):
  X_learn, X_valid = X_train[learn_index], X_train[valid_index]
  y_learn, y_valid = Y_train[learn_index], Y_train[valid_index]
  y_pred_learn = bests_[i].predict(X_learn, num_iteration=bests_[i].best_iteration)
  y_pred_valid = bests_[i].predict(X_valid, num_iteration=bests_[i].best_iteration)
  result.append([accuracy_score(y_learn, np.round(y_pred_learn)), accuracy_score(y_valid, np.round(y_pred_valid))])
  i=i+1
print(result)
# Out:
# [[0.6934375, 0.519375], [0.6041875, 0.517125], [0.5544375, 0.520875], [0.54359375, 0.5185], [0.5545, 0.514]]

# %%
lgb.plot_importance(bests_[0], figsize=(12, 6))
plt.show()

# %%
lgb.plot_importance(bests_[1], figsize=(12, 6))
plt.show()

# %%
lgb.plot_importance(bests_[2], figsize=(12, 6))
plt.show()

# %%
lgb.plot_importance(bests_[3], figsize=(12, 6))
plt.show()

# %%
lgb.plot_importance(bests_[4], figsize=(12, 6))
plt.show()

# %%
y_preds = []
for i in range(5):
    y_pred = bests_[i].predict(X_train, num_iteration=bests_[i].best_iteration)
    y_preds.append(y_pred)
y_pred = (y_preds[0] + y_preds[1]+ y_preds[2]+ y_preds[3]+ y_preds[4])/5

accuracy_score(Y_train, np.round(y_pred))
# Out:
# 0.604925

# %%
y_preds = []
for i in range(5):
    y_pred = bests_[i].predict(X_test, num_iteration=bests_[i].best_iteration)
    y_preds.append(y_pred)
y_pred = (y_preds[0] + y_preds[1]+ y_preds[2]+ y_preds[3]+ y_preds[4])/5
accuracy_score(Y_test, np.round(y_pred))
# Out:
# 0.5112901938881353

# %%
cm = confusion_matrix(np.round(y_pred), Y_test)
cm_matrix = pd.DataFrame(data=cm, columns=['Actual :0', 'Actual :1'],
                                 index=['Predict :0', 'Predict :1'])

sns.heatmap(cm_matrix, annot=True, fmt='d', cmap='YlGnBu')
# Out:
# <Axes: >
