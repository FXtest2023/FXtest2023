# %% [markdown]
# <a href="https://colab.research.google.com/github/FXtest2023/FXtest2023/blob/main/lightGBM_v1_maxdepth3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas_ta
# !pip install optuna
# Out:
# Collecting pandas_ta
#   Downloading pandas_ta-0.3.14b.tar.gz (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.1/115.1 kB 4.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from pandas_ta) (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->pandas_ta) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->pandas_ta) (2022.7.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas->pandas_ta) (1.22.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->pandas_ta) (1.16.0)
# Building wheels for collected packages: pandas_ta
#   Building wheel for pandas_ta (setup.py) ... done
#   Created wheel for pandas_ta: filename=pandas_ta-0.3.14b0-py3-none-any.whl size=218908 sha256=f56706e56f5dbf846c1ac9679144dbdfc63c893566acd64d7c8a14bb2a422d9f
#   Stored in directory: /root/.cache/pip/wheels/69/00/ac/f7fa862c34b0e2ef320175100c233377b4c558944f12474cf0
# Successfully built pandas_ta
# Installing collected packages: pandas_ta
# Successfully installed pandas_ta-0.3.14b0
# Collecting optuna
#   Downloading optuna-3.2.0-py3-none-any.whl (390 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 390.6/390.6 kB 8.4 MB/s eta 0:00:00
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.11.1-py3-none-any.whl (224 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 23.1 MB/s eta 0:00:00
# Collecting cmaes>=0.9.1 (from optuna)
#   Downloading cmaes-0.9.1-py3-none-any.whl (21 kB)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.7.0-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from optuna) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (23.1)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (2.0.18)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from optuna) (4.65.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from optuna) (6.0)
# Collecting Mako (from alembic>=1.5.0->optuna)
#   Downloading Mako-1.2.4-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.7/78.7 kB 10.3 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (4.7.1)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.3.0->optuna) (2.0.2)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from Mako->alembic>=1.5.0->optuna) (2.1.3)
# Installing collected packages: Mako, colorlog, cmaes, alembic, optuna
# Successfully installed Mako-1.2.4 alembic-1.11.1 cmaes-0.9.1 colorlog-6.7.0 optuna-3.2.0

# %%
from google.colab import files
import pandas as pd
import matplotlib.pyplot as plt
import pandas_ta as pd_ta
from sklearn.model_selection import KFold
from optuna.integration import lightgbm as lgb
#import lightgbm as lgb
from sklearn.metrics import confusion_matrix
import seaborn as sns
from sklearn.metrics import accuracy_score
import numpy as np
from sklearn.metrics import log_loss
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import RepeatedKFold

# %%
url = "https://raw.githubusercontent.com/FXtest2023/FXtest2023/5167452d53ac943d8cdb8218a7604a8b530bf465/USDJPY_1H.csv"
df_1H = pd.read_csv(url)

# %%
df_1H
# Out:
#                     utc_datetime  bid_open  bid_high  bid_low  bid_close
# 0      2015-01-01 23:00:00+00:00   119.748   119.819  119.737    119.810
# 1      2015-01-02 00:00:00+00:00   119.809   119.946  119.791    119.866
# 2      2015-01-02 01:00:00+00:00   119.874   120.048  119.831    120.048
# 3      2015-01-02 02:00:00+00:00   120.055   120.382  120.039    120.273
# 4      2015-01-02 03:00:00+00:00   120.266   120.400  120.261    120.325
# ...                          ...       ...       ...      ...        ...
# 52567  2023-07-06 21:00:00+00:00   144.081   144.112  144.040    144.044
# 52568  2023-07-06 22:00:00+00:00   144.023   144.056  143.975    144.005
# 52569  2023-07-06 23:00:00+00:00   144.014   144.049  144.014    144.040
# 52570  2023-07-07 00:00:00+00:00   144.045   144.045  143.881    143.933
# 52571  2023-07-07 01:00:00+00:00   143.952   144.171  143.794    144.067
#
# [52572 rows x 5 columns]

# %%
def calc_features(df):
    open = df['bid_open']
    high = df['bid_high']
    low = df['bid_low']
    close = df['bid_close']
 #   volume = df['volume']

    orig_columns = df.columns

    hilo = (df['bid_high'] + df['bid_low']) / 2
    # 価格(hilo または close)を引いた後、価格(close)で割ることで標準化

    bbands_df = pd_ta.bbands(close, timeperiod=5, nbdevup=2, nbdevdn=2, matype=0)
    df['BBANDS_upperband'] = (bbands_df.iloc[:, 2] - hilo) / close
    df['BBANDS_middleband'] = (bbands_df.iloc[:, 1] - hilo) / close
    df['BBANDS_lowerband'] = (bbands_df.iloc[:, 0] - hilo) / close
    df['DEMA'] = (pd_ta.dema(close, timeperiod=30) - hilo) / close
    df['EMA'] = (pd_ta.ema(close, timeperiod=30) - hilo) / close

#    https://github.com/twopirllc/pandas-ta/issues/411
#    df['HT_TRENDLINE'] = (pd_ta.HT_TRENDLINE(close) - hilo) / close
    df['KAMA'] = (pd_ta.kama(close, timeperiod=30) - hilo) / close
    df['MIDPOINT'] = (pd_ta.midpoint(close, timeperiod=14) - hilo) / close
    df['SMA'] = (pd_ta.sma(close, timeperiod=30) - hilo) / close
    df['T3'] = (pd_ta.t3(close, timeperiod=5, vfactor=0) - hilo) / close
    df['TEMA'] = (pd_ta.tema(close, timeperiod=30) - hilo) / close
    df['TRIMA'] = (pd_ta.trima(close, timeperiod=30) - hilo) / close
    df['WMA'] = (pd_ta.wma(close, timeperiod=30) - hilo) / close
#    df['LINEARREG'] = (pd_ta.LINEARREG(close, timeperiod=14) - close) / close
#    df['LINEARREG_INTERCEPT'] = (pd_ta.LINEARREG_INTERCEPT(close, timeperiod=14) - close) / close


    # 価格(close)で割ることで標準化
#    df['AD'] = pd_ta.AD(high, low, close, volume) / close
#    df['ADOSC'] = pd_ta.ADOSC(high, low, close, volume, fastperiod=3, slowperiod=10) / close
    df['APO'] = pd_ta.apo(close, fastperiod=12, slowperiod=26, matype=0) / close
#    df['HT_PHASOR_inphase'], df['HT_PHASOR_quadrature'] = pd_ta.HT_PHASOR(close)
#    df['HT_PHASOR_inphase'] /= close
#    df['HT_PHASOR_quadrature'] /= close
    df['LINEARREG_SLOPE'] = pd_ta.slope(close, timeperiod=14) / close
    macd = pd_ta.macd(close, fastperiod=12, slowperiod=26, signalperiod=9)
    df['MACD_macd'] = macd.iloc[:, 0] / close
    df['MACD_macdsignal'] =  macd.iloc[:, 1] / close
    df['MACD_macdhist'] =  macd.iloc[:, 2] / close
#    df['MINUS_DM'] = pd_ta.MINUS_DM(high, low, timeperiod=14) / close
    df['MOM'] = pd_ta.mom(close, timeperiod=10) / close
#    df['OBV'] = pd_ta.OBV(close, volume) / close
#    df['PLUS_DM'] = pd_ta.PLUS_DM(high, low, timeperiod=14) / close
    df['STDEV'] = pd_ta.stdev(close, timeperiod=5, nbdev=1) / close
#    df['TRANGE'] = pd_ta.TRANGE(high, low, close) / close


    df['ADX'] = pd_ta.adx(high, low, close, timeperiod=14).iloc[:, 0] / 100
#    df['ADXR'] = pd_ta.ADXR(high, low, close, timeperiod=14)
    aroon = pd_ta.aroon(high, low, timeperiod=14)
    df['AROON_aroondown'] = aroon.iloc[:, 0] / 100
    df['AROON_aroonup'] = aroon.iloc[:, 1] / 100
#    df['AROONOSC'] = pd_ta.AROONOSC(high, low, timeperiod=14)
    df['BOP'] = pd_ta.bop(open, high, low, close)
    df['CCI'] = pd_ta.cci(high, low, close, timeperiod=14) / 100
#    df['DX'] = pd_ta.DX(high, low, close, timeperiod=14)
    # skip MACDEXT MACDFIX たぶん同じなので
#    df['MFI'] = pd_ta.MFI(high, low, close, volume, timeperiod=14)
#    df['MINUS_DI'] = pd_ta.MINUS_DI(high, low, close, timeperiod=14)
#    df['PLUS_DI'] = pd_ta.PLUS_DI(high, low, close, timeperiod=14)
    df['RSI'] = pd_ta.rsi(close, timeperiod=14) / 100

    stoch = pd_ta.stoch(high, low, close, fastk_period=5, slowk_period=3, slowk_matype=0, slowd_period=3, slowd_matype=0)
    df['STOCH_slowk'] = stoch.iloc[:, 0] / 100
    df['STOCH_slowd'] = stoch.iloc[:, 1] / 100

#    df['STOCHF_fastk'], df['STOCHF_fastd'] = pd_ta.STOCHF(high, low, close, fastk_period=5, fastd_period=3, fastd_matype=0)
    stochrsi = pd_ta.stochrsi(close, timeperiod=14, fastk_period=5, fastd_period=3, fastd_matype=0)

    df['STOCHRSI_fastk'] = stochrsi.iloc[:, 0] / 100
    df['STOCHRSI_fastd'] = stochrsi.iloc[:, 1] / 100

    df['TRIX'] = pd_ta.trix(close, timeperiod=30).iloc[:, 1]
#    df['ULTOSC'] = pd_ta.ULTOSC(high, low, close, timeperiod1=7, timeperiod2=14, timeperiod3=28)
    df['WILLR'] = pd_ta.willr(high, low, close, timeperiod=14) / 100

    df['ATR'] = pd_ta.atr(high, low, close, timeperiod=14)
    df['NATR'] = pd_ta.natr(high, low, close, timeperiod=14)

#    df['HT_DCPERIOD'] = pd_ta.HT_DCPERIOD(close)
#    df['HT_DCPHASE'] = pd_ta.HT_DCPHASE(close)
#    df['HT_SINE_sine'], df['HT_SINE_leadsine'] = pd_ta.HT_SINE(close)
#    df['HT_TRENDMODE'] = pd_ta.HT_TRENDMODE(close)

#    df['BETA'] = pd_ta.BETA(high, low, timeperiod=5)
#    df['CORREL'] = pd_ta.cti(high, low, timeperiod=30)

#    df['LINEARREG_ANGLE'] = pd_ta.LINEARREG_ANGLE(close, timeperiod=14)
    return df

df = calc_features(df_1H)
df.dropna(inplace=True)
# df.to_csv('output.csv', index=False, encoding = 'utf-8-sig')
# files.download('output.csv')

# %%
df['diff']  = df['bid_close'].shift(-1) - df['bid_close']
df['label'] = df['diff'].apply(lambda x: 1 if x>0 else 0 )
df.dropna(inplace=True)
df.reset_index(drop=True,inplace=True)
df
# Out:
#                     utc_datetime  bid_open  bid_high  bid_low  bid_close  \
# 0      2015-01-05 13:00:00+00:00   120.257   120.257  120.040    120.118
# 1      2015-01-05 14:00:00+00:00   120.142   120.156  119.758    119.806
# 2      2015-01-05 15:00:00+00:00   119.810   119.814  119.497    119.506
# 3      2015-01-05 16:00:00+00:00   119.471   119.644  119.406    119.624
# 4      2015-01-05 17:00:00+00:00   119.581   119.744  119.443    119.639
# ...                          ...       ...       ...      ...        ...
# 52528  2023-07-06 20:00:00+00:00   144.124   144.137  144.061    144.085
# 52529  2023-07-06 21:00:00+00:00   144.081   144.112  144.040    144.044
# 52530  2023-07-06 22:00:00+00:00   144.023   144.056  143.975    144.005
# 52531  2023-07-06 23:00:00+00:00   144.014   144.049  144.014    144.040
# 52532  2023-07-07 00:00:00+00:00   144.045   144.045  143.881    143.933
#
#        BBANDS_upperband  BBANDS_middleband  BBANDS_lowerband      DEMA  \
# 0              0.002313           0.000843         -0.000626  0.000675
# 1              0.004584           0.001536         -0.001512  0.001027
# 2              0.008033           0.002901         -0.002230  0.001810
# 3              0.007470           0.002785         -0.001900  0.001958
# 4              0.004764           0.001213         -0.002338  0.000760
# ...                 ...                ...               ...       ...
# 52528          0.000512           0.000028         -0.000457 -0.000010
# 52529          0.000719           0.000149         -0.000422  0.000030
# 52530          0.001239           0.000465         -0.000310  0.000272
# 52531          0.000686           0.000176         -0.000335  0.000111
# 52532          0.001114           0.000406         -0.000302  0.000306
#
#             EMA  ...  STOCH_slowk  STOCH_slowd  STOCHRSI_fastk  \
# 0      0.001203  ...     0.375531     0.424923        0.164391
# 1      0.002066  ...     0.209280     0.334552        0.042169
# 2      0.003531  ...     0.085086     0.223299        0.000000
# 3      0.003929  ...     0.082355     0.125574        0.052231
# 4      0.002815  ...     0.128304     0.098582        0.111039
# ...         ...  ...          ...          ...             ...
# 52528 -0.000032  ...     0.531073     0.526051        0.828761
# 52529  0.000064  ...     0.492153     0.517577        0.751853
# 52530  0.000383  ...     0.448063     0.490430        0.675739
# 52531  0.000233  ...     0.423441     0.454552        0.655306
# 52532  0.000542  ...     0.376162     0.415889        0.593326
#
#        STOCHRSI_fastd      TRIX     WILLR       ATR      NATR   diff  label
# 0            0.165157  0.000116 -0.809683  0.188649  0.159261 -0.312      0
# 1            0.123650  0.000096 -0.943195  0.204482  0.182680 -0.300      0
# 2            0.068853  0.000034 -0.991863  0.212957  0.194088  0.118      1
# 3            0.031467 -0.000080 -0.817878  0.214835  0.194571  0.015      1
# 4            0.054423 -0.000254 -0.805347  0.221277  0.202152 -0.078      0
# ...               ...       ...       ...       ...       ...    ...    ...
# 52528        0.836126 -0.004319 -0.502825  0.214143  0.149312 -0.041      0
# 52529        0.809364 -0.004510 -0.541431  0.203990  0.136105 -0.039      0
# 52530        0.752118 -0.004671 -0.611554  0.195205  0.125490  0.035      1
# 52531        0.694299 -0.004809 -0.576693  0.184405  0.112804 -0.107      0
# 52532        0.641457 -0.004932 -0.683267  0.182947  0.113028  0.134      1
#
# [52533 rows x 40 columns]

# %%
len(df[df['label']==1])
# Out:
# 26652

# %%
len(df[df['label']==0])
# Out:
# 25881

# %%
df_train = df[ : 40000]
df_test  = df[40000 : ]

# %%
drop_cols = ['utc_datetime','bid_open',	'bid_high',	'bid_low','bid_close', 'diff','label']
X_train=df_train.drop(columns=drop_cols).values
Y_train=df_train['label'].values
Y_train = Y_train.reshape(-1)

X_test=df_test.drop(columns=drop_cols).values
Y_test=df_test['label'].values
Y_test = Y_test.reshape(-1)

# %%
# 乱数シードの固定
SEED = 123

# LightGBM訓練用関数を定義
def trainGbdt(X_train, y_train):
    bests = []
    kf = KFold(n_splits=5, shuffle=False)
    for learn_index, valid_index in kf.split(X_train, y_train):
        X_learn, X_valid = X_train[learn_index], X_train[valid_index]
        y_learn, y_valid = y_train[learn_index], y_train[valid_index]

        #LGB用のデータに変形
        lgb_learn = lgb.Dataset(X_learn, y_learn)
        lgb_valid = lgb.Dataset(X_valid, y_valid)

        param = {
            'objective': 'binary',
            'metric': 'auc',
            'boosting_type': 'gbdt',
            'random_seed':SEED,
            'max_depth':3,
            'verbose':-1,
#            'device': 'gpu',
 #           'force_col_wise': True,
        }

        # 訓練実施
        best = lgb.train(param,
                         lgb_learn,
                         valid_sets=[lgb_learn,lgb_valid],
                         verbose_eval=False
                        )
        bests.append(best)

    return bests

# %%
bests_ = trainGbdt(X_train, Y_train)
# Out:
# [I 2023-07-12 11:17:55,319] A new study created in memory with name: no-name-d970721d-a0ef-4742-b31f-4b2bcfe7518b
# feature_fraction, val_score: -inf:   0%|          | 0/7 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# feature_fraction, val_score: 0.515503:  14%|#4        | 1/7 [00:24<02:28, 24.72s/it][I 2023-07-12 11:18:20,066] Trial 0 finished with value: 0.5155031826049432 and parameters: {'feature_fraction': 1.0}. Best is trial 0 with value: 0.5155031826049432.
# feature_fraction, val_score: 0.520291:  29%|##8       | 2/7 [00:34<01:18, 15.67s/it][I 2023-07-12 11:18:29,395] Trial 1 finished with value: 0.5202909660222951 and parameters: {'feature_fraction': 0.4}. Best is trial 1 with value: 0.5202909660222951.
# feature_fraction, val_score: 0.520291:  43%|####2     | 3/7 [00:44<00:52, 13.06s/it][I 2023-07-12 11:18:39,351] Trial 2 finished with value: 0.5200352600475384 and parameters: {'feature_fraction': 0.5}. Best is trial 1 with value: 0.5202909660222951.
# feature_fraction, val_score: 0.520291:  57%|#####7    | 4/7 [00:53<00:34, 11.62s/it][I 2023-07-12 11:18:48,774] Trial 3 finished with value: 0.5189711831679839 and parameters: {'feature_fraction': 0.7}. Best is trial 1 with value: 0.5202909660222951.
# feature_fraction, val_score: 0.520291:  71%|#######1  | 5/7 [01:00<00:20, 10.07s/it][I 2023-07-12 11:18:56,097] Trial 4 finished with value: 0.5193247712147203 and parameters: {'feature_fraction': 0.8}. Best is trial 1 with value: 0.5202909660222951.
# feature_fraction, val_score: 0.520291:  86%|########5 | 6/7 [01:10<00:10, 10.07s/it][I 2023-07-12 11:19:06,159] Trial 5 finished with value: 0.5188764888263177 and parameters: {'feature_fraction': 0.8999999999999999}. Best is trial 1 with value: 0.5202909660222951.
# feature_fraction, val_score: 0.520291: 100%|##########| 7/7 [01:19<00:00,  9.76s/it][I 2023-07-12 11:19:15,293] Trial 6 finished with value: 0.5197675532057191 and parameters: {'feature_fraction': 0.6}. Best is trial 1 with value: 0.5202909660222951.
# feature_fraction, val_score: 0.520291: 100%|##########| 7/7 [01:19<00:00, 11.42s/it]
# num_leaves, val_score: 0.522070:   5%|5         | 1/20 [00:06<02:07,  6.73s/it][I 2023-07-12 11:19:22,041] Trial 7 finished with value: 0.5220697820417525 and parameters: {'num_leaves': 6}. Best is trial 7 with value: 0.5220697820417525.
# num_leaves, val_score: 0.522119:  10%|#         | 2/20 [00:14<02:12,  7.38s/it][I 2023-07-12 11:19:29,865] Trial 8 finished with value: 0.5221185355641945 and parameters: {'num_leaves': 3}. Best is trial 8 with value: 0.5221185355641945.
# num_leaves, val_score: 0.527382:  15%|#5        | 3/20 [00:23<02:21,  8.31s/it][I 2023-07-12 11:19:39,292] Trial 9 finished with value: 0.5273821658614835 and parameters: {'num_leaves': 5}. Best is trial 9 with value: 0.5273821658614835.
# num_leaves, val_score: 0.527382:  20%|##        | 4/20 [00:31<02:05,  7.81s/it][I 2023-07-12 11:19:46,344] Trial 10 finished with value: 0.5202909660222951 and parameters: {'num_leaves': 8}. Best is trial 9 with value: 0.5273821658614835.
# num_leaves, val_score: 0.527382:  25%|##5       | 5/20 [00:39<01:59,  8.00s/it][I 2023-07-12 11:19:54,672] Trial 11 finished with value: 0.5203596584853256 and parameters: {'num_leaves': 2}. Best is trial 9 with value: 0.5273821658614835.
# num_leaves, val_score: 0.527382:  30%|###       | 6/20 [00:45<01:43,  7.43s/it][I 2023-07-12 11:20:00,994] Trial 12 finished with value: 0.5221185355641945 and parameters: {'num_leaves': 3}. Best is trial 9 with value: 0.5273821658614835.
# num_leaves, val_score: 0.527382:  35%|###5      | 7/20 [00:54<01:42,  7.85s/it][I 2023-07-12 11:20:09,697] Trial 13 finished with value: 0.5197314255954992 and parameters: {'num_leaves': 4}. Best is trial 9 with value: 0.5273821658614835.
# num_leaves, val_score: 0.527382:  40%|####      | 8/20 [01:03<01:38,  8.19s/it][I 2023-07-12 11:20:18,619] Trial 14 finished with value: 0.5273821658614835 and parameters: {'num_leaves': 5}. Best is trial 9 with value: 0.5273821658614835.
# num_leaves, val_score: 0.527382:  45%|####5     | 9/20 [01:10<01:25,  7.76s/it][I 2023-07-12 11:20:25,426] Trial 15 finished with value: 0.5220697820417525 and parameters: {'num_leaves': 6}. Best is trial 9 with value: 0.5273821658614835.
# num_leaves, val_score: 0.527382:  50%|#####     | 10/20 [01:19<01:21,  8.11s/it][I 2023-07-12 11:20:34,314] Trial 16 finished with value: 0.5273821658614835 and parameters: {'num_leaves': 5}. Best is trial 9 with value: 0.5273821658614835.
# num_leaves, val_score: 0.527382:  55%|#####5    | 11/20 [01:28<01:15,  8.38s/it][I 2023-07-12 11:20:43,323] Trial 17 finished with value: 0.5220697820417525 and parameters: {'num_leaves': 6}. Best is trial 9 with value: 0.5273821658614835.
# num_leaves, val_score: 0.527382:  60%|######    | 12/20 [01:34<01:02,  7.81s/it][I 2023-07-12 11:20:49,809] Trial 18 finished with value: 0.5273821658614835 and parameters: {'num_leaves': 5}. Best is trial 9 with value: 0.5273821658614835.
# num_leaves, val_score: 0.527382:  65%|######5   | 13/20 [01:43<00:57,  8.27s/it][I 2023-07-12 11:20:59,148] Trial 19 finished with value: 0.5202909660222951 and parameters: {'num_leaves': 8}. Best is trial 9 with value: 0.5273821658614835.
# num_leaves, val_score: 0.527382:  70%|#######   | 14/20 [01:52<00:50,  8.41s/it][I 2023-07-12 11:21:07,873] Trial 20 finished with value: 0.5197314255954992 and parameters: {'num_leaves': 4}. Best is trial 9 with value: 0.5273821658614835.
# num_leaves, val_score: 0.527382:  75%|#######5  | 15/20 [01:59<00:39,  7.84s/it][I 2023-07-12 11:21:14,414] Trial 21 finished with value: 0.5273821658614835 and parameters: {'num_leaves': 5}. Best is trial 9 with value: 0.5273821658614835.
# num_leaves, val_score: 0.527382:  80%|########  | 16/20 [02:07<00:31,  7.92s/it][I 2023-07-12 11:21:22,515] Trial 22 finished with value: 0.5273821658614835 and parameters: {'num_leaves': 5}. Best is trial 9 with value: 0.5273821658614835.
# num_leaves, val_score: 0.527382:  85%|########5 | 17/20 [02:16<00:24,  8.31s/it][I 2023-07-12 11:21:31,725] Trial 23 finished with value: 0.5185985937483983 and parameters: {'num_leaves': 7}. Best is trial 9 with value: 0.5273821658614835.
# num_leaves, val_score: 0.527382:  90%|######### | 18/20 [02:22<00:15,  7.75s/it][I 2023-07-12 11:21:38,181] Trial 24 finished with value: 0.5197314255954992 and parameters: {'num_leaves': 4}. Best is trial 9 with value: 0.5273821658614835.
# num_leaves, val_score: 0.527382:  95%|#########5| 19/20 [02:31<00:07,  7.91s/it][I 2023-07-12 11:21:46,452] Trial 25 finished with value: 0.5220697820417525 and parameters: {'num_leaves': 6}. Best is trial 9 with value: 0.5273821658614835.
# num_leaves, val_score: 0.527382: 100%|##########| 20/20 [02:37<00:00,  7.47s/it][I 2023-07-12 11:21:52,903] Trial 26 finished with value: 0.5197314255954992 and parameters: {'num_leaves': 4}. Best is trial 9 with value: 0.5273821658614835.
# num_leaves, val_score: 0.527382: 100%|##########| 20/20 [02:37<00:00,  7.88s/it]
# bagging, val_score: 0.527382:  10%|#         | 1/10 [00:09<01:22,  9.14s/it][I 2023-07-12 11:22:02,056] Trial 27 finished with value: 0.5206576800173812 and parameters: {'bagging_fraction': 0.8147433156753247, 'bagging_freq': 1}. Best is trial 27 with value: 0.5206576800173812.
# bagging, val_score: 0.527382:  20%|##        | 2/10 [00:19<01:19,  9.97s/it][I 2023-07-12 11:22:12,612] Trial 28 finished with value: 0.5203725969201275 and parameters: {'bagging_fraction': 0.46526957205902997, 'bagging_freq': 7}. Best is trial 27 with value: 0.5206576800173812.
# bagging, val_score: 0.527382:  30%|###       | 3/10 [00:26<01:00,  8.64s/it][I 2023-07-12 11:22:19,658] Trial 29 finished with value: 0.5208501939265112 and parameters: {'bagging_fraction': 0.9384427115602507, 'bagging_freq': 4}. Best is trial 29 with value: 0.5208501939265112.
# bagging, val_score: 0.527382:  40%|####      | 4/10 [00:35<00:52,  8.68s/it][I 2023-07-12 11:22:28,396] Trial 30 finished with value: 0.5164433755338823 and parameters: {'bagging_fraction': 0.603333913650008, 'bagging_freq': 7}. Best is trial 29 with value: 0.5208501939265112.
# bagging, val_score: 0.527382:  50%|#####     | 5/10 [00:44<00:44,  8.87s/it][I 2023-07-12 11:22:37,622] Trial 31 finished with value: 0.5213387292231864 and parameters: {'bagging_fraction': 0.4108439832143059, 'bagging_freq': 1}. Best is trial 31 with value: 0.5213387292231864.
# bagging, val_score: 0.527382:  60%|######    | 6/10 [00:51<00:33,  8.26s/it][I 2023-07-12 11:22:44,697] Trial 32 finished with value: 0.5243156318043979 and parameters: {'bagging_fraction': 0.9957899221636073, 'bagging_freq': 4}. Best is trial 32 with value: 0.5243156318043979.
# bagging, val_score: 0.527382:  70%|#######   | 7/10 [01:00<00:24,  8.33s/it][I 2023-07-12 11:22:53,152] Trial 33 finished with value: 0.521576496401865 and parameters: {'bagging_fraction': 0.707336342344438, 'bagging_freq': 5}. Best is trial 32 with value: 0.5243156318043979.
# bagging, val_score: 0.527382:  80%|########  | 8/10 [01:08<00:16,  8.41s/it][I 2023-07-12 11:23:01,746] Trial 34 finished with value: 0.5185894055845535 and parameters: {'bagging_fraction': 0.5584442157435242, 'bagging_freq': 3}. Best is trial 32 with value: 0.5243156318043979.
# bagging, val_score: 0.527382:  90%|######### | 9/10 [01:14<00:07,  7.71s/it][I 2023-07-12 11:23:07,915] Trial 35 finished with value: 0.5161607926172666 and parameters: {'bagging_fraction': 0.8029785658557146, 'bagging_freq': 6}. Best is trial 32 with value: 0.5243156318043979.
# bagging, val_score: 0.527382: 100%|##########| 10/10 [01:23<00:00,  8.01s/it][I 2023-07-12 11:23:16,592] Trial 36 finished with value: 0.5159697788165195 and parameters: {'bagging_fraction': 0.540303944063348, 'bagging_freq': 2}. Best is trial 32 with value: 0.5243156318043979.
# bagging, val_score: 0.527382: 100%|##########| 10/10 [01:23<00:00,  8.37s/it]
# feature_fraction_stage2, val_score: 0.527382:  33%|###3      | 1/3 [00:06<00:13,  6.83s/it][I 2023-07-12 11:23:23,441] Trial 37 finished with value: 0.5258676189354681 and parameters: {'feature_fraction': 0.44800000000000006}. Best is trial 37 with value: 0.5258676189354681.
# feature_fraction_stage2, val_score: 0.527382:  67%|######6   | 2/3 [00:15<00:07,  7.62s/it][I 2023-07-12 11:23:31,610] Trial 38 finished with value: 0.5228173985570458 and parameters: {'feature_fraction': 0.48000000000000004}. Best is trial 37 with value: 0.5258676189354681.
# feature_fraction_stage2, val_score: 0.527382: 100%|##########| 3/3 [00:23<00:00,  8.21s/it][I 2023-07-12 11:23:40,518] Trial 39 finished with value: 0.5219546487233703 and parameters: {'feature_fraction': 0.41600000000000004}. Best is trial 37 with value: 0.5258676189354681.
# feature_fraction_stage2, val_score: 0.527382: 100%|##########| 3/3 [00:23<00:00,  7.97s/it]
# regularization_factors, val_score: 0.527382:   5%|5         | 1/20 [00:05<01:51,  5.85s/it][I 2023-07-12 11:23:46,385] Trial 40 finished with value: 0.5211914685836052 and parameters: {'lambda_l1': 0.10557569874217516, 'lambda_l2': 4.119394308271145e-06}. Best is trial 40 with value: 0.5211914685836052.
# regularization_factors, val_score: 0.527382:  10%|#         | 2/20 [00:14<02:17,  7.64s/it][I 2023-07-12 11:23:55,276] Trial 41 finished with value: 0.518487460719037 and parameters: {'lambda_l1': 1.4135600645408096e-08, 'lambda_l2': 3.632079093422519}. Best is trial 40 with value: 0.5211914685836052.
# regularization_factors, val_score: 0.527382:  15%|#5        | 3/20 [00:23<02:15,  7.97s/it][I 2023-07-12 11:24:03,633] Trial 42 finished with value: 0.5199360028762078 and parameters: {'lambda_l1': 6.8252825602523055, 'lambda_l2': 1.2674769408761803e-08}. Best is trial 40 with value: 0.5211914685836052.
# regularization_factors, val_score: 0.527382:  20%|##        | 4/20 [00:29<01:58,  7.42s/it][I 2023-07-12 11:24:10,218] Trial 43 finished with value: 0.5189689330054097 and parameters: {'lambda_l1': 7.191854801493889e-05, 'lambda_l2': 0.07439682433829624}. Best is trial 40 with value: 0.5211914685836052.
# regularization_factors, val_score: 0.527382:  25%|##5       | 5/20 [00:38<01:59,  7.97s/it][I 2023-07-12 11:24:19,157] Trial 44 finished with value: 0.5273821658614835 and parameters: {'lambda_l1': 5.16812126972715e-05, 'lambda_l2': 0.0014128962662835415}. Best is trial 44 with value: 0.5273821658614835.
# regularization_factors, val_score: 0.527382:  30%|###       | 6/20 [00:45<01:45,  7.51s/it][I 2023-07-12 11:24:25,774] Trial 45 finished with value: 0.5273821658614835 and parameters: {'lambda_l1': 1.5434701098523004e-08, 'lambda_l2': 6.848254496463348e-05}. Best is trial 44 with value: 0.5273821658614835.
# regularization_factors, val_score: 0.527382:  35%|###5      | 7/20 [00:54<01:43,  7.99s/it][I 2023-07-12 11:24:34,744] Trial 46 finished with value: 0.5225266275488404 and parameters: {'lambda_l1': 0.005831249875679444, 'lambda_l2': 6.124527649144654}. Best is trial 44 with value: 0.5273821658614835.
# regularization_factors, val_score: 0.527382:  40%|####      | 8/20 [01:03<01:39,  8.28s/it][I 2023-07-12 11:24:43,667] Trial 47 finished with value: 0.5273822283659995 and parameters: {'lambda_l1': 3.834862718167555e-06, 'lambda_l2': 7.546205966059765e-08}. Best is trial 47 with value: 0.5273822283659995.
# regularization_factors, val_score: 0.527382:  45%|####5     | 9/20 [01:09<01:25,  7.75s/it][I 2023-07-12 11:24:50,251] Trial 48 finished with value: 0.5273822283659995 and parameters: {'lambda_l1': 2.153387183698724e-06, 'lambda_l2': 1.1887499301622718e-08}. Best is trial 47 with value: 0.5273822283659995.
# regularization_factors, val_score: 0.527382:  50%|#####     | 10/20 [01:18<01:21,  8.11s/it][I 2023-07-12 11:24:59,169] Trial 49 finished with value: 0.5273822283659995 and parameters: {'lambda_l1': 1.6316572596771423e-06, 'lambda_l2': 1.0316665024553998e-08}. Best is trial 47 with value: 0.5273822283659995.
# regularization_factors, val_score: 0.527382:  55%|#####5    | 11/20 [01:27<01:15,  8.36s/it][I 2023-07-12 11:25:08,106] Trial 50 finished with value: 0.5273822283659995 and parameters: {'lambda_l1': 2.4653997215466313e-06, 'lambda_l2': 1.3389041090403143e-08}. Best is trial 47 with value: 0.5273822283659995.
# regularization_factors, val_score: 0.527382:  60%|######    | 12/20 [01:34<01:02,  7.83s/it][I 2023-07-12 11:25:14,704] Trial 51 finished with value: 0.5273822283659995 and parameters: {'lambda_l1': 3.4203385818688485e-06, 'lambda_l2': 1.1925283340165293e-08}. Best is trial 47 with value: 0.5273822283659995.
# regularization_factors, val_score: 0.527382:  65%|######5   | 13/20 [01:43<00:57,  8.15s/it][I 2023-07-12 11:25:23,597] Trial 52 finished with value: 0.5273822283659995 and parameters: {'lambda_l1': 3.0809520912931126e-06, 'lambda_l2': 1.107049501602909e-08}. Best is trial 47 with value: 0.5273822283659995.
# regularization_factors, val_score: 0.527382:  70%|#######   | 14/20 [01:51<00:50,  8.37s/it][I 2023-07-12 11:25:32,487] Trial 53 finished with value: 0.5273822283659995 and parameters: {'lambda_l1': 2.3722910103348448e-06, 'lambda_l2': 1.0353580803048273e-08}. Best is trial 47 with value: 0.5273822283659995.
# regularization_factors, val_score: 0.527382:  75%|#######5  | 15/20 [01:58<00:39,  7.83s/it][I 2023-07-12 11:25:39,059] Trial 54 finished with value: 0.5273822283659995 and parameters: {'lambda_l1': 2.2600194329658913e-06, 'lambda_l2': 1.1770149715943276e-08}. Best is trial 47 with value: 0.5273822283659995.
# regularization_factors, val_score: 0.527382:  80%|########  | 16/20 [02:07<00:32,  8.17s/it][I 2023-07-12 11:25:48,010] Trial 55 finished with value: 0.5273822283659995 and parameters: {'lambda_l1': 1.76228919298854e-06, 'lambda_l2': 1.0534729363853426e-08}. Best is trial 47 with value: 0.5273822283659995.
# regularization_factors, val_score: 0.527382:  85%|########5 | 17/20 [02:16<00:25,  8.41s/it][I 2023-07-12 11:25:56,970] Trial 56 finished with value: 0.5273822283659995 and parameters: {'lambda_l1': 2.102078541341062e-06, 'lambda_l2': 1.0428574934970886e-07}. Best is trial 47 with value: 0.5273822283659995.
# regularization_factors, val_score: 0.527382:  90%|######### | 18/20 [02:23<00:15,  7.87s/it][I 2023-07-12 11:26:03,593] Trial 57 finished with value: 0.5273822283659995 and parameters: {'lambda_l1': 2.077481917134012e-06, 'lambda_l2': 1.7612979357061298e-07}. Best is trial 47 with value: 0.5273822283659995.
# regularization_factors, val_score: 0.527382:  95%|#########5| 19/20 [02:31<00:08,  8.17s/it][I 2023-07-12 11:26:12,457] Trial 58 finished with value: 0.5273823533750314 and parameters: {'lambda_l1': 9.52042576758452e-06, 'lambda_l2': 1.6388686123511656e-07}. Best is trial 58 with value: 0.5273823533750314.
# regularization_factors, val_score: 0.527382: 100%|##########| 20/20 [02:43<00:00,  9.08s/it][I 2023-07-12 11:26:23,675] Trial 59 finished with value: 0.5273823533750314 and parameters: {'lambda_l1': 1.387923265144504e-05, 'lambda_l2': 2.3338096774829016e-07}. Best is trial 58 with value: 0.5273823533750314.
# regularization_factors, val_score: 0.527382: 100%|##########| 20/20 [02:43<00:00,  8.16s/it]
# min_data_in_leaf, val_score: 0.527382:  20%|##        | 1/5 [00:06<00:26,  6.68s/it][I 2023-07-12 11:26:30,373] Trial 60 finished with value: 0.5175958963035079 and parameters: {'min_child_samples': 50}. Best is trial 60 with value: 0.5175958963035079.
# min_data_in_leaf, val_score: 0.527382:  40%|####      | 2/5 [00:15<00:23,  8.00s/it][I 2023-07-12 11:26:39,290] Trial 61 finished with value: 0.5236952744835814 and parameters: {'min_child_samples': 25}. Best is trial 61 with value: 0.5236952744835814.
# min_data_in_leaf, val_score: 0.527382:  60%|######    | 3/5 [00:24<00:16,  8.43s/it][I 2023-07-12 11:26:48,239] Trial 62 finished with value: 0.5214812395195553 and parameters: {'min_child_samples': 5}. Best is trial 61 with value: 0.5236952744835814.
# min_data_in_leaf, val_score: 0.527382:  80%|########  | 4/5 [00:31<00:07,  7.71s/it][I 2023-07-12 11:26:54,839] Trial 63 finished with value: 0.5228476507427662 and parameters: {'min_child_samples': 10}. Best is trial 61 with value: 0.5236952744835814.
# min_data_in_leaf, val_score: 0.527382: 100%|##########| 5/5 [00:39<00:00,  7.88s/it][I 2023-07-12 11:27:03,008] Trial 64 finished with value: 0.521668878076441 and parameters: {'min_child_samples': 100}. Best is trial 61 with value: 0.5236952744835814.
# min_data_in_leaf, val_score: 0.527382: 100%|##########| 5/5 [00:39<00:00,  7.86s/it]
# [I 2023-07-12 11:27:03,020] A new study created in memory with name: no-name-4b96309c-01b4-4d9c-9045-2ea29083091b
# feature_fraction, val_score: 0.504161:  14%|#4        | 1/7 [00:09<00:56,  9.42s/it][I 2023-07-12 11:27:12,447] Trial 0 finished with value: 0.5041613246430791 and parameters: {'feature_fraction': 0.7}. Best is trial 0 with value: 0.5041613246430791.
# feature_fraction, val_score: 0.507093:  29%|##8       | 2/7 [00:16<00:39,  7.90s/it][I 2023-07-12 11:27:19,282] Trial 1 finished with value: 0.5070931009464781 and parameters: {'feature_fraction': 0.6}. Best is trial 1 with value: 0.5070931009464781.
# feature_fraction, val_score: 0.511537:  43%|####2     | 3/7 [00:26<00:35,  8.85s/it][I 2023-07-12 11:27:29,275] Trial 2 finished with value: 0.5115373645366893 and parameters: {'feature_fraction': 0.8999999999999999}. Best is trial 2 with value: 0.5115373645366893.
# feature_fraction, val_score: 0.511537:  57%|#####7    | 4/7 [00:35<00:27,  9.04s/it][I 2023-07-12 11:27:38,605] Trial 3 finished with value: 0.5108714750848395 and parameters: {'feature_fraction': 0.4}. Best is trial 2 with value: 0.5115373645366893.
# feature_fraction, val_score: 0.511537:  71%|#######1  | 5/7 [00:43<00:17,  8.57s/it][I 2023-07-12 11:27:46,340] Trial 4 finished with value: 0.5100075627489702 and parameters: {'feature_fraction': 1.0}. Best is trial 2 with value: 0.5115373645366893.
# feature_fraction, val_score: 0.511537:  86%|########5 | 6/7 [00:52<00:08,  8.67s/it][I 2023-07-12 11:27:55,213] Trial 5 finished with value: 0.5101896462909995 and parameters: {'feature_fraction': 0.5}. Best is trial 2 with value: 0.5115373645366893.
# feature_fraction, val_score: 0.511537: 100%|##########| 7/7 [01:01<00:00,  9.01s/it][I 2023-07-12 11:28:04,904] Trial 6 finished with value: 0.5103107227829016 and parameters: {'feature_fraction': 0.8}. Best is trial 2 with value: 0.5115373645366893.
# feature_fraction, val_score: 0.511537: 100%|##########| 7/7 [01:01<00:00,  8.84s/it]
# num_leaves, val_score: 0.513761:   5%|5         | 1/20 [00:08<02:44,  8.67s/it][I 2023-07-12 11:28:13,588] Trial 7 finished with value: 0.5137611215196056 and parameters: {'num_leaves': 4}. Best is trial 7 with value: 0.5137611215196056.
# num_leaves, val_score: 0.514809:  10%|#         | 2/20 [00:15<02:13,  7.40s/it][I 2023-07-12 11:28:20,096] Trial 8 finished with value: 0.5148090551214325 and parameters: {'num_leaves': 2}. Best is trial 8 with value: 0.5148090551214325.
# num_leaves, val_score: 0.514809:  15%|#5        | 3/20 [00:25<02:25,  8.53s/it][I 2023-07-12 11:28:29,986] Trial 9 finished with value: 0.5075668431933166 and parameters: {'num_leaves': 7}. Best is trial 8 with value: 0.5148090551214325.
# num_leaves, val_score: 0.514809:  20%|##        | 4/20 [00:31<02:01,  7.60s/it][I 2023-07-12 11:28:36,140] Trial 10 finished with value: 0.5148090551214325 and parameters: {'num_leaves': 2}. Best is trial 8 with value: 0.5148090551214325.
# num_leaves, val_score: 0.514809:  25%|##5       | 5/20 [00:39<01:58,  7.90s/it][I 2023-07-12 11:28:44,594] Trial 11 finished with value: 0.5148090551214325 and parameters: {'num_leaves': 2}. Best is trial 8 with value: 0.5148090551214325.
# num_leaves, val_score: 0.514809:  30%|###       | 6/20 [00:48<01:53,  8.10s/it][I 2023-07-12 11:28:53,060] Trial 12 finished with value: 0.5148090551214325 and parameters: {'num_leaves': 2}. Best is trial 8 with value: 0.5148090551214325.
# num_leaves, val_score: 0.514809:  35%|###5      | 7/20 [00:54<01:39,  7.69s/it][I 2023-07-12 11:28:59,910] Trial 13 finished with value: 0.5137611215196056 and parameters: {'num_leaves': 4}. Best is trial 8 with value: 0.5148090551214325.
# num_leaves, val_score: 0.514809:  40%|####      | 8/20 [01:03<01:35,  7.92s/it][I 2023-07-12 11:29:08,334] Trial 14 finished with value: 0.5148090551214325 and parameters: {'num_leaves': 2}. Best is trial 8 with value: 0.5148090551214325.
# num_leaves, val_score: 0.514809:  45%|####5     | 9/20 [01:12<01:31,  8.31s/it][I 2023-07-12 11:29:17,498] Trial 15 finished with value: 0.5137611215196056 and parameters: {'num_leaves': 4}. Best is trial 8 with value: 0.5148090551214325.
# num_leaves, val_score: 0.514809:  50%|#####     | 10/20 [01:19<01:20,  8.01s/it][I 2023-07-12 11:29:24,842] Trial 16 finished with value: 0.509813790356148 and parameters: {'num_leaves': 6}. Best is trial 8 with value: 0.5148090551214325.
# num_leaves, val_score: 0.518031:  55%|#####5    | 11/20 [01:28<01:14,  8.31s/it][I 2023-07-12 11:29:33,821] Trial 17 finished with value: 0.5180310524635003 and parameters: {'num_leaves': 3}. Best is trial 17 with value: 0.5180310524635003.
# num_leaves, val_score: 0.518031:  60%|######    | 12/20 [01:37<01:08,  8.51s/it][I 2023-07-12 11:29:42,780] Trial 18 finished with value: 0.5180310524635003 and parameters: {'num_leaves': 3}. Best is trial 17 with value: 0.5180310524635003.
# num_leaves, val_score: 0.518031:  65%|######5   | 13/20 [01:44<00:56,  8.05s/it][I 2023-07-12 11:29:49,795] Trial 19 finished with value: 0.5151717845393509 and parameters: {'num_leaves': 5}. Best is trial 17 with value: 0.5180310524635003.
# num_leaves, val_score: 0.518031:  70%|#######   | 14/20 [01:53<00:49,  8.30s/it][I 2023-07-12 11:29:58,659] Trial 20 finished with value: 0.5180310524635003 and parameters: {'num_leaves': 3}. Best is trial 17 with value: 0.5180310524635003.
# num_leaves, val_score: 0.518031:  75%|#######5  | 15/20 [02:02<00:42,  8.51s/it][I 2023-07-12 11:30:07,659] Trial 21 finished with value: 0.5180310524635003 and parameters: {'num_leaves': 3}. Best is trial 17 with value: 0.5180310524635003.
# num_leaves, val_score: 0.518031:  80%|########  | 16/20 [02:09<00:31,  7.96s/it][I 2023-07-12 11:30:14,331] Trial 22 finished with value: 0.5180310524635003 and parameters: {'num_leaves': 3}. Best is trial 17 with value: 0.5180310524635003.
# num_leaves, val_score: 0.518031:  85%|########5 | 17/20 [02:20<00:26,  8.97s/it][I 2023-07-12 11:30:25,652] Trial 23 finished with value: 0.5180310524635003 and parameters: {'num_leaves': 3}. Best is trial 17 with value: 0.5180310524635003.
# num_leaves, val_score: 0.518031:  90%|######### | 18/20 [02:30<00:18,  9.10s/it][I 2023-07-12 11:30:35,053] Trial 24 finished with value: 0.5151717845393509 and parameters: {'num_leaves': 5}. Best is trial 17 with value: 0.5180310524635003.
# num_leaves, val_score: 0.518031:  95%|#########5| 19/20 [02:40<00:09,  9.34s/it][I 2023-07-12 11:30:44,964] Trial 25 finished with value: 0.5115373645366893 and parameters: {'num_leaves': 8}. Best is trial 17 with value: 0.5180310524635003.
# num_leaves, val_score: 0.518031: 100%|##########| 20/20 [02:46<00:00,  8.55s/it][I 2023-07-12 11:30:51,676] Trial 26 finished with value: 0.5180310524635003 and parameters: {'num_leaves': 3}. Best is trial 17 with value: 0.5180310524635003.
# num_leaves, val_score: 0.518031: 100%|##########| 20/20 [02:46<00:00,  8.34s/it]
# bagging, val_score: 0.518031:  10%|#         | 1/10 [00:09<01:23,  9.27s/it][I 2023-07-12 11:31:00,961] Trial 27 finished with value: 0.5175574352311089 and parameters: {'bagging_fraction': 0.8822000259354004, 'bagging_freq': 6}. Best is trial 27 with value: 0.5175574352311089.
# bagging, val_score: 0.518031:  20%|##        | 2/10 [00:18<01:13,  9.16s/it][I 2023-07-12 11:31:10,049] Trial 28 finished with value: 0.5114460414831689 and parameters: {'bagging_fraction': 0.43118275304626064, 'bagging_freq': 1}. Best is trial 27 with value: 0.5175574352311089.
# bagging, val_score: 0.518031:  30%|###       | 3/10 [00:25<00:59,  8.45s/it][I 2023-07-12 11:31:17,652] Trial 29 finished with value: 0.5167368404011189 and parameters: {'bagging_fraction': 0.9911380883967692, 'bagging_freq': 2}. Best is trial 27 with value: 0.5175574352311089.
# bagging, val_score: 0.518031:  40%|####      | 4/10 [00:34<00:51,  8.54s/it][I 2023-07-12 11:31:26,329] Trial 30 finished with value: 0.510840096458647 and parameters: {'bagging_fraction': 0.626851946406123, 'bagging_freq': 6}. Best is trial 27 with value: 0.5175574352311089.
# bagging, val_score: 0.518031:  50%|#####     | 5/10 [00:43<00:43,  8.71s/it][I 2023-07-12 11:31:35,332] Trial 31 finished with value: 0.5124787858296874 and parameters: {'bagging_fraction': 0.7173391080603848, 'bagging_freq': 4}. Best is trial 27 with value: 0.5175574352311089.
# bagging, val_score: 0.518031:  60%|######    | 6/10 [00:49<00:31,  7.85s/it][I 2023-07-12 11:31:41,510] Trial 32 finished with value: 0.514147791204121 and parameters: {'bagging_fraction': 0.42181379395740504, 'bagging_freq': 3}. Best is trial 27 with value: 0.5175574352311089.
# bagging, val_score: 0.518031:  70%|#######   | 7/10 [00:58<00:24,  8.19s/it][I 2023-07-12 11:31:50,400] Trial 33 finished with value: 0.5168415400004663 and parameters: {'bagging_fraction': 0.7471208439527507, 'bagging_freq': 7}. Best is trial 27 with value: 0.5175574352311089.
# bagging, val_score: 0.518031:  80%|########  | 8/10 [01:05<00:15,  7.60s/it][I 2023-07-12 11:31:56,738] Trial 34 finished with value: 0.5157484136760554 and parameters: {'bagging_fraction': 0.5744872884363459, 'bagging_freq': 5}. Best is trial 27 with value: 0.5175574352311089.
# bagging, val_score: 0.518031:  90%|######### | 9/10 [01:14<00:08,  8.14s/it][I 2023-07-12 11:32:06,071] Trial 35 finished with value: 0.5172654639901824 and parameters: {'bagging_fraction': 0.8444357469808524, 'bagging_freq': 1}. Best is trial 27 with value: 0.5175574352311089.
# bagging, val_score: 0.518031: 100%|##########| 10/10 [01:23<00:00,  8.32s/it][I 2023-07-12 11:32:14,791] Trial 36 finished with value: 0.5152921109445711 and parameters: {'bagging_fraction': 0.5307265114412362, 'bagging_freq': 3}. Best is trial 27 with value: 0.5175574352311089.
# bagging, val_score: 0.518031: 100%|##########| 10/10 [01:23<00:00,  8.31s/it]
# feature_fraction_stage2, val_score: 0.519135:  17%|#6        | 1/6 [00:06<00:32,  6.54s/it][I 2023-07-12 11:32:21,344] Trial 37 finished with value: 0.5191348050159047 and parameters: {'feature_fraction': 0.82}. Best is trial 37 with value: 0.5191348050159047.
# feature_fraction_stage2, val_score: 0.519135:  33%|###3      | 2/6 [00:15<00:32,  8.00s/it][I 2023-07-12 11:32:30,374] Trial 38 finished with value: 0.5178788473742997 and parameters: {'feature_fraction': 0.9799999999999999}. Best is trial 37 with value: 0.5191348050159047.
# feature_fraction_stage2, val_score: 0.519135:  50%|#####     | 3/6 [00:24<00:25,  8.42s/it][I 2023-07-12 11:32:39,298] Trial 39 finished with value: 0.5180310524635003 and parameters: {'feature_fraction': 0.9159999999999999}. Best is trial 37 with value: 0.5191348050159047.
# feature_fraction_stage2, val_score: 0.519135:  67%|######6   | 4/6 [00:30<00:15,  7.66s/it][I 2023-07-12 11:32:45,796] Trial 40 finished with value: 0.5188801505874022 and parameters: {'feature_fraction': 0.852}. Best is trial 37 with value: 0.5191348050159047.
# feature_fraction_stage2, val_score: 0.519135:  83%|########3 | 5/6 [00:39<00:08,  8.12s/it][I 2023-07-12 11:32:54,721] Trial 41 finished with value: 0.517087318403233 and parameters: {'feature_fraction': 0.8839999999999999}. Best is trial 37 with value: 0.5191348050159047.
# feature_fraction_stage2, val_score: 0.519247: 100%|##########| 6/6 [00:48<00:00,  8.43s/it][I 2023-07-12 11:33:03,764] Trial 42 finished with value: 0.5192470679892945 and parameters: {'feature_fraction': 0.948}. Best is trial 42 with value: 0.5192470679892945.
# feature_fraction_stage2, val_score: 0.519247: 100%|##########| 6/6 [00:48<00:00,  8.16s/it]
# regularization_factors, val_score: 0.519247:   5%|5         | 1/20 [00:06<02:10,  6.86s/it][I 2023-07-12 11:33:10,643] Trial 43 finished with value: 0.517995360838887 and parameters: {'lambda_l1': 2.3154952434134504e-08, 'lambda_l2': 0.0334681049416756}. Best is trial 43 with value: 0.517995360838887.
# regularization_factors, val_score: 0.519247:  10%|#         | 2/20 [00:16<02:27,  8.22s/it][I 2023-07-12 11:33:19,816] Trial 44 finished with value: 0.5188259568246355 and parameters: {'lambda_l1': 1.0538671460090592, 'lambda_l2': 1.0382230695321467e-08}. Best is trial 44 with value: 0.5188259568246355.
# regularization_factors, val_score: 0.519247:  15%|#5        | 3/20 [00:25<02:27,  8.65s/it][I 2023-07-12 11:33:28,977] Trial 45 finished with value: 0.5183385254958526 and parameters: {'lambda_l1': 1.5665608236665036, 'lambda_l2': 1.887070686989681e-08}. Best is trial 44 with value: 0.5188259568246355.
# regularization_factors, val_score: 0.519247:  20%|##        | 4/20 [00:32<02:08,  8.04s/it][I 2023-07-12 11:33:36,097] Trial 46 finished with value: 0.5163802991983261 and parameters: {'lambda_l1': 5.151203260400822, 'lambda_l2': 1.195235374011934e-08}. Best is trial 44 with value: 0.5188259568246355.
# regularization_factors, val_score: 0.519247:  25%|##5       | 5/20 [00:41<02:07,  8.48s/it][I 2023-07-12 11:33:45,338] Trial 47 finished with value: 0.5182555159030565 and parameters: {'lambda_l1': 3.1833230618829775, 'lambda_l2': 1.1073539432786391e-08}. Best is trial 44 with value: 0.5188259568246355.
# regularization_factors, val_score: 0.519247:  30%|###       | 6/20 [00:50<02:01,  8.69s/it][I 2023-07-12 11:33:54,442] Trial 48 finished with value: 0.5182899573832 and parameters: {'lambda_l1': 0.05609920393860883, 'lambda_l2': 3.0786593765832477e-06}. Best is trial 44 with value: 0.5188259568246355.
# regularization_factors, val_score: 0.520239:  35%|###5      | 7/20 [00:57<01:45,  8.10s/it][I 2023-07-12 11:34:01,316] Trial 49 finished with value: 0.5202387450899795 and parameters: {'lambda_l1': 0.006309528301662878, 'lambda_l2': 8.871898099470501e-06}. Best is trial 49 with value: 0.5202387450899795.
# regularization_factors, val_score: 0.520239:  40%|####      | 8/20 [01:06<01:41,  8.43s/it][I 2023-07-12 11:34:10,446] Trial 50 finished with value: 0.5181118117962507 and parameters: {'lambda_l1': 0.00471507689007384, 'lambda_l2': 4.5529292841010146e-05}. Best is trial 49 with value: 0.5202387450899795.
# regularization_factors, val_score: 0.520239:  45%|####5     | 9/20 [01:15<01:35,  8.67s/it][I 2023-07-12 11:34:19,646] Trial 51 finished with value: 0.5171220724194939 and parameters: {'lambda_l1': 0.1368411317747798, 'lambda_l2': 5.404452091889835e-07}. Best is trial 49 with value: 0.5202387450899795.
# regularization_factors, val_score: 0.520239:  50%|#####     | 10/20 [01:22<01:20,  8.10s/it][I 2023-07-12 11:34:26,467] Trial 52 finished with value: 0.5189382197980255 and parameters: {'lambda_l1': 0.00047385847678652716, 'lambda_l2': 2.6620322524214e-07}. Best is trial 49 with value: 0.5202387450899795.
# regularization_factors, val_score: 0.520239:  55%|#####5    | 11/20 [01:33<01:21,  9.08s/it][I 2023-07-12 11:34:37,779] Trial 53 finished with value: 0.5189380947835784 and parameters: {'lambda_l1': 0.0003560518168840585, 'lambda_l2': 1.7957668613192973e-06}. Best is trial 49 with value: 0.5202387450899795.
# regularization_factors, val_score: 0.520239:  60%|######    | 12/20 [01:43<01:12,  9.08s/it][I 2023-07-12 11:34:46,847] Trial 54 finished with value: 0.5189382823052489 and parameters: {'lambda_l1': 0.00020291336824799052, 'lambda_l2': 6.720327599452022e-06}. Best is trial 49 with value: 0.5202387450899795.
# regularization_factors, val_score: 0.520239:  65%|######5   | 13/20 [01:52<01:03,  9.07s/it][I 2023-07-12 11:34:55,905] Trial 55 finished with value: 0.5189382823052489 and parameters: {'lambda_l1': 0.00032865706167129925, 'lambda_l2': 6.381552103773106e-06}. Best is trial 49 with value: 0.5202387450899795.
# regularization_factors, val_score: 0.520239:  70%|#######   | 14/20 [01:58<00:50,  8.39s/it][I 2023-07-12 11:35:02,714] Trial 56 finished with value: 0.518938157290802 and parameters: {'lambda_l1': 0.00017061069229905833, 'lambda_l2': 5.049262004902576e-05}. Best is trial 49 with value: 0.5202387450899795.
# regularization_factors, val_score: 0.520239:  75%|#######5  | 15/20 [02:08<00:42,  8.60s/it][I 2023-07-12 11:35:11,795] Trial 57 finished with value: 0.5189382823052489 and parameters: {'lambda_l1': 0.0002421450912327257, 'lambda_l2': 9.640603341189932e-06}. Best is trial 49 with value: 0.5202387450899795.
# regularization_factors, val_score: 0.520239:  80%|########  | 16/20 [02:17<00:35,  8.77s/it][I 2023-07-12 11:35:20,953] Trial 58 finished with value: 0.5192470679892945 and parameters: {'lambda_l1': 4.429772327262936e-05, 'lambda_l2': 2.903290477292459e-05}. Best is trial 49 with value: 0.5202387450899795.
# regularization_factors, val_score: 0.520239:  85%|########5 | 17/20 [02:24<00:24,  8.19s/it][I 2023-07-12 11:35:27,806] Trial 59 finished with value: 0.5189380947835784 and parameters: {'lambda_l1': 1.099609773534209e-05, 'lambda_l2': 0.0006354522482339141}. Best is trial 49 with value: 0.5202387450899795.
# regularization_factors, val_score: 0.520239:  90%|######### | 18/20 [02:33<00:16,  8.48s/it][I 2023-07-12 11:35:36,958] Trial 60 finished with value: 0.519247130496518 and parameters: {'lambda_l1': 5.253894594481787e-05, 'lambda_l2': 0.0002249088080557321}. Best is trial 49 with value: 0.5202387450899795.
# regularization_factors, val_score: 0.520239:  95%|#########5| 19/20 [02:42<00:08,  8.68s/it][I 2023-07-12 11:35:46,104] Trial 61 finished with value: 0.5192470679892945 and parameters: {'lambda_l1': 1.8218834275158736e-05, 'lambda_l2': 0.0002244642519876761}. Best is trial 49 with value: 0.5202387450899795.
# regularization_factors, val_score: 0.520239: 100%|##########| 20/20 [02:49<00:00,  8.13s/it][I 2023-07-12 11:35:52,959] Trial 62 finished with value: 0.5192474430326355 and parameters: {'lambda_l1': 1.9948830700330073e-05, 'lambda_l2': 0.000415390454289811}. Best is trial 49 with value: 0.5202387450899795.
# regularization_factors, val_score: 0.520239: 100%|##########| 20/20 [02:49<00:00,  8.46s/it]
# min_data_in_leaf, val_score: 0.520239:  20%|##        | 1/5 [00:09<00:36,  9.22s/it][I 2023-07-12 11:36:02,199] Trial 63 finished with value: 0.5197473758061166 and parameters: {'min_child_samples': 25}. Best is trial 63 with value: 0.5197473758061166.
# min_data_in_leaf, val_score: 0.520239:  40%|####      | 2/5 [00:18<00:27,  9.20s/it][I 2023-07-12 11:36:11,387] Trial 64 finished with value: 0.5167384030817062 and parameters: {'min_child_samples': 50}. Best is trial 63 with value: 0.5197473758061166.
# min_data_in_leaf, val_score: 0.520239:  60%|######    | 3/5 [00:25<00:16,  8.14s/it][I 2023-07-12 11:36:18,258] Trial 65 finished with value: 0.5168921083442706 and parameters: {'min_child_samples': 5}. Best is trial 63 with value: 0.5197473758061166.
# min_data_in_leaf, val_score: 0.520239:  80%|########  | 4/5 [00:34<00:08,  8.56s/it][I 2023-07-12 11:36:27,475] Trial 66 finished with value: 0.5147034804209561 and parameters: {'min_child_samples': 100}. Best is trial 63 with value: 0.5197473758061166.
# min_data_in_leaf, val_score: 0.520239: 100%|##########| 5/5 [00:43<00:00,  8.76s/it][I 2023-07-12 11:36:36,580] Trial 67 finished with value: 0.5166297030200553 and parameters: {'min_child_samples': 10}. Best is trial 63 with value: 0.5197473758061166.
# min_data_in_leaf, val_score: 0.520239: 100%|##########| 5/5 [00:43<00:00,  8.72s/it]
# [I 2023-07-12 11:36:36,591] A new study created in memory with name: no-name-ac6c294a-e1ba-45d5-be9c-354488fddaad
# feature_fraction, val_score: 0.519973:  14%|#4        | 1/7 [00:06<00:40,  6.82s/it][I 2023-07-12 11:36:43,422] Trial 0 finished with value: 0.5199727709005452 and parameters: {'feature_fraction': 0.6}. Best is trial 0 with value: 0.5199727709005452.
# feature_fraction, val_score: 0.519973:  29%|##8       | 2/7 [00:16<00:43,  8.73s/it][I 2023-07-12 11:36:53,490] Trial 1 finished with value: 0.5177468007778635 and parameters: {'feature_fraction': 1.0}. Best is trial 0 with value: 0.5199727709005452.
# feature_fraction, val_score: 0.519973:  43%|####2     | 3/7 [00:26<00:35,  8.99s/it][I 2023-07-12 11:37:02,787] Trial 2 finished with value: 0.5182601926617677 and parameters: {'feature_fraction': 0.4}. Best is trial 0 with value: 0.5199727709005452.
# feature_fraction, val_score: 0.519973:  57%|#####7    | 4/7 [00:33<00:24,  8.27s/it][I 2023-07-12 11:37:09,944] Trial 3 finished with value: 0.5180175403993497 and parameters: {'feature_fraction': 0.7}. Best is trial 0 with value: 0.5199727709005452.
# feature_fraction, val_score: 0.519973:  71%|#######1  | 5/7 [00:42<00:17,  8.77s/it][I 2023-07-12 11:37:19,601] Trial 4 finished with value: 0.5167146998039953 and parameters: {'feature_fraction': 0.8}. Best is trial 0 with value: 0.5199727709005452.
# feature_fraction, val_score: 0.520111:  86%|########5 | 6/7 [00:52<00:09,  9.17s/it][I 2023-07-12 11:37:29,567] Trial 5 finished with value: 0.5201111433688279 and parameters: {'feature_fraction': 0.5}. Best is trial 5 with value: 0.5201111433688279.
# feature_fraction, val_score: 0.521294: 100%|##########| 7/7 [01:02<00:00,  9.44s/it][I 2023-07-12 11:37:39,540] Trial 6 finished with value: 0.521294378105522 and parameters: {'feature_fraction': 0.8999999999999999}. Best is trial 6 with value: 0.521294378105522.
# feature_fraction, val_score: 0.521294: 100%|##########| 7/7 [01:02<00:00,  8.99s/it]
# num_leaves, val_score: 0.521294:   5%|5         | 1/20 [00:07<02:25,  7.67s/it][I 2023-07-12 11:37:47,238] Trial 7 finished with value: 0.521294378105522 and parameters: {'num_leaves': 8}. Best is trial 7 with value: 0.521294378105522.
# num_leaves, val_score: 0.521294:  10%|#         | 2/20 [00:16<02:35,  8.64s/it][I 2023-07-12 11:37:56,550] Trial 8 finished with value: 0.5154521448639636 and parameters: {'num_leaves': 5}. Best is trial 7 with value: 0.521294378105522.
# num_leaves, val_score: 0.521294:  15%|#5        | 3/20 [00:26<02:31,  8.90s/it][I 2023-07-12 11:38:05,758] Trial 9 finished with value: 0.5146856852493009 and parameters: {'num_leaves': 4}. Best is trial 7 with value: 0.521294378105522.
# num_leaves, val_score: 0.521294:  20%|##        | 4/20 [00:32<02:05,  7.84s/it][I 2023-07-12 11:38:11,979] Trial 10 finished with value: 0.5199934767264952 and parameters: {'num_leaves': 2}. Best is trial 7 with value: 0.521294378105522.
# num_leaves, val_score: 0.521294:  25%|##5       | 5/20 [00:42<02:08,  8.60s/it][I 2023-07-12 11:38:21,922] Trial 11 finished with value: 0.521294378105522 and parameters: {'num_leaves': 8}. Best is trial 7 with value: 0.521294378105522.
# num_leaves, val_score: 0.521294:  30%|###       | 6/20 [00:52<02:06,  9.07s/it][I 2023-07-12 11:38:31,895] Trial 12 finished with value: 0.521294378105522 and parameters: {'num_leaves': 8}. Best is trial 7 with value: 0.521294378105522.
# num_leaves, val_score: 0.521294:  35%|###5      | 7/20 [01:02<02:02,  9.41s/it][I 2023-07-12 11:38:42,006] Trial 13 finished with value: 0.516403799637917 and parameters: {'num_leaves': 7}. Best is trial 7 with value: 0.521294378105522.
# num_leaves, val_score: 0.521294:  40%|####      | 8/20 [01:11<01:51,  9.33s/it][I 2023-07-12 11:38:51,169] Trial 14 finished with value: 0.5167112592588978 and parameters: {'num_leaves': 6}. Best is trial 7 with value: 0.521294378105522.
# num_leaves, val_score: 0.521294:  45%|####5     | 9/20 [01:20<01:41,  9.23s/it][I 2023-07-12 11:39:00,183] Trial 15 finished with value: 0.5163500958567142 and parameters: {'num_leaves': 3}. Best is trial 7 with value: 0.521294378105522.
# num_leaves, val_score: 0.521294:  50%|#####     | 10/20 [01:30<01:33,  9.37s/it][I 2023-07-12 11:39:09,863] Trial 16 finished with value: 0.5167112592588978 and parameters: {'num_leaves': 6}. Best is trial 7 with value: 0.521294378105522.
# num_leaves, val_score: 0.521294:  55%|#####5    | 11/20 [01:37<01:19,  8.82s/it][I 2023-07-12 11:39:17,444] Trial 17 finished with value: 0.516403799637917 and parameters: {'num_leaves': 7}. Best is trial 7 with value: 0.521294378105522.
# num_leaves, val_score: 0.521294:  60%|######    | 12/20 [01:47<01:11,  9.00s/it][I 2023-07-12 11:39:26,838] Trial 18 finished with value: 0.5154521448639636 and parameters: {'num_leaves': 5}. Best is trial 7 with value: 0.521294378105522.
# num_leaves, val_score: 0.521294:  65%|######5   | 13/20 [01:57<01:04,  9.25s/it][I 2023-07-12 11:39:36,681] Trial 19 finished with value: 0.516403799637917 and parameters: {'num_leaves': 7}. Best is trial 7 with value: 0.521294378105522.
# num_leaves, val_score: 0.521294:  70%|#######   | 14/20 [02:06<00:55,  9.25s/it][I 2023-07-12 11:39:45,930] Trial 20 finished with value: 0.5146856852493009 and parameters: {'num_leaves': 4}. Best is trial 7 with value: 0.521294378105522.
# num_leaves, val_score: 0.521294:  75%|#######5  | 15/20 [02:14<00:43,  8.77s/it][I 2023-07-12 11:39:53,581] Trial 21 finished with value: 0.521294378105522 and parameters: {'num_leaves': 8}. Best is trial 7 with value: 0.521294378105522.
# num_leaves, val_score: 0.521294:  80%|########  | 16/20 [02:23<00:36,  9.13s/it][I 2023-07-12 11:40:03,539] Trial 22 finished with value: 0.521294378105522 and parameters: {'num_leaves': 8}. Best is trial 7 with value: 0.521294378105522.
# num_leaves, val_score: 0.521294:  85%|########5 | 17/20 [02:33<00:27,  9.28s/it][I 2023-07-12 11:40:13,190] Trial 23 finished with value: 0.5167112592588978 and parameters: {'num_leaves': 6}. Best is trial 7 with value: 0.521294378105522.
# num_leaves, val_score: 0.521294:  90%|######### | 18/20 [02:41<00:17,  8.82s/it][I 2023-07-12 11:40:20,932] Trial 24 finished with value: 0.521294378105522 and parameters: {'num_leaves': 8}. Best is trial 7 with value: 0.521294378105522.
# num_leaves, val_score: 0.521294:  95%|#########5| 19/20 [02:51<00:09,  9.09s/it][I 2023-07-12 11:40:30,636] Trial 25 finished with value: 0.516403799637917 and parameters: {'num_leaves': 7}. Best is trial 7 with value: 0.521294378105522.
# num_leaves, val_score: 0.521294: 100%|##########| 20/20 [03:00<00:00,  9.26s/it][I 2023-07-12 11:40:40,286] Trial 26 finished with value: 0.5167112592588978 and parameters: {'num_leaves': 6}. Best is trial 7 with value: 0.521294378105522.
# num_leaves, val_score: 0.521294: 100%|##########| 20/20 [03:00<00:00,  9.04s/it]
# bagging, val_score: 0.521294:  10%|#         | 1/10 [00:10<01:36, 10.70s/it][I 2023-07-12 11:40:51,002] Trial 27 finished with value: 0.5201140209156366 and parameters: {'bagging_fraction': 0.9346427932824524, 'bagging_freq': 7}. Best is trial 27 with value: 0.5201140209156366.
# bagging, val_score: 0.521294:  20%|##        | 2/10 [00:20<01:23, 10.44s/it][I 2023-07-12 11:41:01,251] Trial 28 finished with value: 0.5161450080912238 and parameters: {'bagging_fraction': 0.42991815212617507, 'bagging_freq': 1}. Best is trial 27 with value: 0.5201140209156366.
# bagging, val_score: 0.521294:  30%|###       | 3/10 [00:29<01:07,  9.57s/it][I 2023-07-12 11:41:09,797] Trial 29 finished with value: 0.5146228483847485 and parameters: {'bagging_fraction': 0.9404482669719927, 'bagging_freq': 4}. Best is trial 27 with value: 0.5201140209156366.
# bagging, val_score: 0.521294:  40%|####      | 4/10 [00:39<00:58,  9.77s/it][I 2023-07-12 11:41:19,877] Trial 30 finished with value: 0.5178603387660792 and parameters: {'bagging_fraction': 0.595304992081279, 'bagging_freq': 1}. Best is trial 27 with value: 0.5201140209156366.
# bagging, val_score: 0.521294:  50%|#####     | 5/10 [00:49<00:49,  9.95s/it][I 2023-07-12 11:41:30,146] Trial 31 finished with value: 0.5150995828245236 and parameters: {'bagging_fraction': 0.7298864415524804, 'bagging_freq': 7}. Best is trial 27 with value: 0.5201140209156366.
# bagging, val_score: 0.521294:  60%|######    | 6/10 [00:59<00:39,  9.83s/it][I 2023-07-12 11:41:39,740] Trial 32 finished with value: 0.5166547092085689 and parameters: {'bagging_fraction': 0.433328350319575, 'bagging_freq': 4}. Best is trial 27 with value: 0.5201140209156366.
# bagging, val_score: 0.521294:  70%|#######   | 7/10 [01:07<00:27,  9.26s/it][I 2023-07-12 11:41:47,828] Trial 33 finished with value: 0.5164481513919914 and parameters: {'bagging_fraction': 0.7639689320038081, 'bagging_freq': 5}. Best is trial 27 with value: 0.5201140209156366.
# bagging, val_score: 0.526185:  80%|########  | 8/10 [01:17<00:19,  9.55s/it][I 2023-07-12 11:41:57,991] Trial 34 finished with value: 0.5261845186855691 and parameters: {'bagging_fraction': 0.5921170822369282, 'bagging_freq': 3}. Best is trial 34 with value: 0.5261845186855691.
# bagging, val_score: 0.526185:  90%|######### | 9/10 [01:27<00:09,  9.74s/it][I 2023-07-12 11:42:08,160] Trial 35 finished with value: 0.5166261214065774 and parameters: {'bagging_fraction': 0.5895933737365853, 'bagging_freq': 3}. Best is trial 34 with value: 0.5261845186855691.
# bagging, val_score: 0.526185: 100%|##########| 10/10 [01:38<00:00,  9.91s/it][I 2023-07-12 11:42:18,442] Trial 36 finished with value: 0.5217480296154615 and parameters: {'bagging_fraction': 0.5950695352416727, 'bagging_freq': 2}. Best is trial 34 with value: 0.5261845186855691.
# bagging, val_score: 0.526185: 100%|##########| 10/10 [01:38<00:00,  9.82s/it]
# feature_fraction_stage2, val_score: 0.526185:  17%|#6        | 1/6 [00:10<00:51, 10.20s/it][I 2023-07-12 11:42:28,670] Trial 37 finished with value: 0.5227621771994576 and parameters: {'feature_fraction': 0.9799999999999999}. Best is trial 37 with value: 0.5227621771994576.
# feature_fraction_stage2, val_score: 0.526185:  33%|###3      | 2/6 [00:18<00:35,  8.97s/it][I 2023-07-12 11:42:36,778] Trial 38 finished with value: 0.5188114930971093 and parameters: {'feature_fraction': 0.948}. Best is trial 37 with value: 0.5227621771994576.
# ...
# num_leaves, val_score: 0.514310:  30%|###       | 6/20 [00:46<01:46,  7.58s/it][I 2023-07-12 11:57:48,149] Trial 12 finished with value: 0.5143102286955328 and parameters: {'num_leaves': 2}. Best is trial 10 with value: 0.5143102286955328.
# num_leaves, val_score: 0.514310:  35%|###5      | 7/20 [00:53<01:33,  7.22s/it][I 2023-07-12 11:57:54,616] Trial 13 finished with value: 0.5092383280190356 and parameters: {'num_leaves': 4}. Best is trial 10 with value: 0.5143102286955328.
# num_leaves, val_score: 0.514310:  40%|####      | 8/20 [01:01<01:30,  7.51s/it][I 2023-07-12 11:58:02,757] Trial 14 finished with value: 0.5143102286955328 and parameters: {'num_leaves': 2}. Best is trial 10 with value: 0.5143102286955328.
# num_leaves, val_score: 0.514310:  45%|####5     | 9/20 [01:10<01:26,  7.91s/it][I 2023-07-12 11:58:11,541] Trial 15 finished with value: 0.5092383280190356 and parameters: {'num_leaves': 4}. Best is trial 10 with value: 0.5143102286955328.
# num_leaves, val_score: 0.514310:  50%|#####     | 10/20 [01:19<01:23,  8.38s/it][I 2023-07-12 11:58:20,977] Trial 16 finished with value: 0.5143102286955328 and parameters: {'num_leaves': 2}. Best is trial 10 with value: 0.5143102286955328.
# num_leaves, val_score: 0.514310:  55%|#####5    | 11/20 [01:28<01:16,  8.49s/it][I 2023-07-12 11:58:29,721] Trial 17 finished with value: 0.5092383280190356 and parameters: {'num_leaves': 4}. Best is trial 10 with value: 0.5143102286955328.
# num_leaves, val_score: 0.514310:  60%|######    | 12/20 [01:37<01:10,  8.80s/it][I 2023-07-12 11:58:39,242] Trial 18 finished with value: 0.5076345699000101 and parameters: {'num_leaves': 8}. Best is trial 10 with value: 0.5143102286955328.
# num_leaves, val_score: 0.514310:  65%|######5   | 13/20 [01:48<01:06,  9.43s/it][I 2023-07-12 11:58:50,114] Trial 19 finished with value: 0.5119530292622106 and parameters: {'num_leaves': 3}. Best is trial 10 with value: 0.5143102286955328.
# num_leaves, val_score: 0.514310:  70%|#######   | 14/20 [01:55<00:51,  8.56s/it][I 2023-07-12 11:58:56,670] Trial 20 finished with value: 0.5081516975179687 and parameters: {'num_leaves': 5}. Best is trial 10 with value: 0.5143102286955328.
# num_leaves, val_score: 0.514310:  75%|#######5  | 15/20 [02:03<00:42,  8.44s/it][I 2023-07-12 11:59:04,817] Trial 21 finished with value: 0.5143102286955328 and parameters: {'num_leaves': 2}. Best is trial 10 with value: 0.5143102286955328.
# num_leaves, val_score: 0.514310:  80%|########  | 16/20 [02:09<00:31,  7.79s/it][I 2023-07-12 11:59:11,104] Trial 22 finished with value: 0.5119530292622106 and parameters: {'num_leaves': 3}. Best is trial 10 with value: 0.5143102286955328.
# num_leaves, val_score: 0.514310:  85%|########5 | 17/20 [02:17<00:23,  7.96s/it][I 2023-07-12 11:59:19,474] Trial 23 finished with value: 0.5143102286955328 and parameters: {'num_leaves': 2}. Best is trial 10 with value: 0.5143102286955328.
# num_leaves, val_score: 0.514310:  90%|######### | 18/20 [02:26<00:16,  8.13s/it][I 2023-07-12 11:59:27,982] Trial 24 finished with value: 0.5119530292622106 and parameters: {'num_leaves': 3}. Best is trial 10 with value: 0.5143102286955328.
# num_leaves, val_score: 0.514310:  95%|#########5| 19/20 [02:32<00:07,  7.43s/it][I 2023-07-12 11:59:33,793] Trial 25 finished with value: 0.5143102286955328 and parameters: {'num_leaves': 2}. Best is trial 10 with value: 0.5143102286955328.
# num_leaves, val_score: 0.514310: 100%|##########| 20/20 [02:41<00:00,  7.91s/it][I 2023-07-12 11:59:42,826] Trial 26 finished with value: 0.5119530292622106 and parameters: {'num_leaves': 3}. Best is trial 10 with value: 0.5143102286955328.
# num_leaves, val_score: 0.514310: 100%|##########| 20/20 [02:41<00:00,  8.07s/it]
# bagging, val_score: 0.514310:  10%|#         | 1/10 [00:05<00:52,  5.85s/it][I 2023-07-12 11:59:48,701] Trial 27 finished with value: 0.5141457903630637 and parameters: {'bagging_fraction': 0.5955806300753207, 'bagging_freq': 3}. Best is trial 27 with value: 0.5141457903630637.
# bagging, val_score: 0.514540:  20%|##        | 2/10 [00:14<00:59,  7.42s/it][I 2023-07-12 11:59:57,217] Trial 28 finished with value: 0.5145397298573824 and parameters: {'bagging_fraction': 0.9923816526450043, 'bagging_freq': 6}. Best is trial 28 with value: 0.5145397298573824.
# bagging, val_score: 0.514723:  30%|###       | 3/10 [00:22<00:55,  7.91s/it][I 2023-07-12 12:00:05,700] Trial 29 finished with value: 0.5147229182847738 and parameters: {'bagging_fraction': 0.9969510934418497, 'bagging_freq': 7}. Best is trial 29 with value: 0.5147229182847738.
# bagging, val_score: 0.515104:  40%|####      | 4/10 [00:29<00:43,  7.25s/it][I 2023-07-12 12:00:11,951] Trial 30 finished with value: 0.5151042952154945 and parameters: {'bagging_fraction': 0.9820509869514893, 'bagging_freq': 7}. Best is trial 30 with value: 0.5151042952154945.
# bagging, val_score: 0.515104:  50%|#####     | 5/10 [00:37<00:38,  7.70s/it][I 2023-07-12 12:00:20,448] Trial 31 finished with value: 0.5149942321583003 and parameters: {'bagging_fraction': 0.9869023892681363, 'bagging_freq': 7}. Best is trial 30 with value: 0.5151042952154945.
# bagging, val_score: 0.515104:  60%|######    | 6/10 [00:43<00:28,  7.19s/it][I 2023-07-12 12:00:26,658] Trial 32 finished with value: 0.5146584804585573 and parameters: {'bagging_fraction': 0.993156531250333, 'bagging_freq': 7}. Best is trial 30 with value: 0.5151042952154945.
# bagging, val_score: 0.515104:  70%|#######   | 7/10 [00:52<00:22,  7.61s/it][I 2023-07-12 12:00:35,111] Trial 33 finished with value: 0.5143024161559818 and parameters: {'bagging_fraction': 0.9987775882763962, 'bagging_freq': 7}. Best is trial 30 with value: 0.5151042952154945.
# bagging, val_score: 0.515104:  80%|########  | 8/10 [01:00<00:15,  7.89s/it][I 2023-07-12 12:00:43,625] Trial 34 finished with value: 0.514302291155349 and parameters: {'bagging_fraction': 0.9882422904850574, 'bagging_freq': 7}. Best is trial 30 with value: 0.5151042952154945.
# bagging, val_score: 0.515574:  90%|######### | 9/10 [01:06<00:07,  7.36s/it][I 2023-07-12 12:00:49,797] Trial 35 finished with value: 0.5155735475910846 and parameters: {'bagging_fraction': 0.9770663760530893, 'bagging_freq': 7}. Best is trial 35 with value: 0.5155735475910846.
# bagging, val_score: 0.515574: 100%|##########| 10/10 [01:15<00:00,  7.67s/it][I 2023-07-12 12:00:58,177] Trial 36 finished with value: 0.5137562571410518 and parameters: {'bagging_fraction': 0.8510582999725396, 'bagging_freq': 5}. Best is trial 35 with value: 0.5155735475910846.
# bagging, val_score: 0.515574: 100%|##########| 10/10 [01:15<00:00,  7.53s/it]
# feature_fraction_stage2, val_score: 0.515574:  17%|#6        | 1/6 [00:06<00:31,  6.36s/it][I 2023-07-12 12:01:04,553] Trial 37 finished with value: 0.5154321093750537 and parameters: {'feature_fraction': 0.7799999999999999}. Best is trial 37 with value: 0.5154321093750537.
# feature_fraction_stage2, val_score: 0.515876:  33%|###3      | 2/6 [00:14<00:30,  7.66s/it][I 2023-07-12 12:01:13,114] Trial 38 finished with value: 0.5158756116202838 and parameters: {'feature_fraction': 0.748}. Best is trial 38 with value: 0.5158756116202838.
# feature_fraction_stage2, val_score: 0.515876:  50%|#####     | 3/6 [00:23<00:24,  8.05s/it][I 2023-07-12 12:01:21,630] Trial 39 finished with value: 0.5155735475910846 and parameters: {'feature_fraction': 0.6839999999999999}. Best is trial 38 with value: 0.5158756116202838.
# feature_fraction_stage2, val_score: 0.515876:  67%|######6   | 4/6 [00:29<00:14,  7.22s/it][I 2023-07-12 12:01:27,588] Trial 40 finished with value: 0.5154702970683789 and parameters: {'feature_fraction': 0.62}. Best is trial 38 with value: 0.5158756116202838.
# feature_fraction_stage2, val_score: 0.515876:  83%|########3 | 5/6 [00:37<00:07,  7.63s/it][I 2023-07-12 12:01:35,952] Trial 41 finished with value: 0.5155186723132786 and parameters: {'feature_fraction': 0.652}. Best is trial 38 with value: 0.5158756116202838.
# feature_fraction_stage2, val_score: 0.516393: 100%|##########| 6/6 [00:44<00:00,  7.22s/it][I 2023-07-12 12:01:42,371] Trial 42 finished with value: 0.5163926142376096 and parameters: {'feature_fraction': 0.716}. Best is trial 42 with value: 0.5163926142376096.
# feature_fraction_stage2, val_score: 0.516393: 100%|##########| 6/6 [00:44<00:00,  7.36s/it]
# regularization_factors, val_score: 0.516393:   5%|5         | 1/20 [00:08<02:38,  8.32s/it][I 2023-07-12 12:01:50,720] Trial 43 finished with value: 0.5163933642414065 and parameters: {'lambda_l1': 1.5830500896037305e-08, 'lambda_l2': 0.00847676886598572}. Best is trial 43 with value: 0.5163933642414065.
# regularization_factors, val_score: 0.516393:  10%|#         | 2/20 [00:16<02:32,  8.49s/it][I 2023-07-12 12:01:59,320] Trial 44 finished with value: 0.5163933017410901 and parameters: {'lambda_l1': 1.6054651615751536e-08, 'lambda_l2': 0.009244882789891731}. Best is trial 43 with value: 0.5163933642414065.
# regularization_factors, val_score: 0.516393:  15%|#5        | 3/20 [00:23<02:07,  7.49s/it][I 2023-07-12 12:02:05,627] Trial 45 finished with value: 0.5153104212590076 and parameters: {'lambda_l1': 1.0078586092357984e-08, 'lambda_l2': 0.012858329507324606}. Best is trial 43 with value: 0.5163933642414065.
# regularization_factors, val_score: 0.516393:  20%|##        | 4/20 [00:31<02:06,  7.92s/it][I 2023-07-12 12:02:14,199] Trial 46 finished with value: 0.5158249863639934 and parameters: {'lambda_l1': 1.839196068617007e-08, 'lambda_l2': 0.011127619559404082}. Best is trial 43 with value: 0.5163933642414065.
# regularization_factors, val_score: 0.516393:  25%|##5       | 5/20 [00:40<02:02,  8.16s/it][I 2023-07-12 12:02:22,785] Trial 47 finished with value: 0.5163925517372931 and parameters: {'lambda_l1': 1.9567637930562602e-08, 'lambda_l2': 0.00395426576301773}. Best is trial 43 with value: 0.5163933642414065.
# regularization_factors, val_score: 0.516393:  30%|###       | 6/20 [00:46<01:45,  7.51s/it][I 2023-07-12 12:02:29,034] Trial 48 finished with value: 0.5163925517372931 and parameters: {'lambda_l1': 2.017142148746576e-08, 'lambda_l2': 0.0025016388902288377}. Best is trial 43 with value: 0.5163933642414065.
# regularization_factors, val_score: 0.516393:  35%|###5      | 7/20 [00:57<01:51,  8.58s/it][I 2023-07-12 12:02:39,817] Trial 49 finished with value: 0.5163930517398244 and parameters: {'lambda_l1': 2.497269564047525e-08, 'lambda_l2': 0.005750458406016742}. Best is trial 43 with value: 0.5163933642414065.
# regularization_factors, val_score: 0.516393:  40%|####      | 8/20 [01:05<01:42,  8.57s/it][I 2023-07-12 12:02:48,355] Trial 50 finished with value: 0.516392989239508 and parameters: {'lambda_l1': 2.3924154830093085e-08, 'lambda_l2': 0.005266668017379289}. Best is trial 43 with value: 0.5163933642414065.
# regularization_factors, val_score: 0.516393:  45%|####5     | 9/20 [01:12<01:26,  7.84s/it][I 2023-07-12 12:02:54,611] Trial 51 finished with value: 0.5163932392407736 and parameters: {'lambda_l1': 2.2916695608053948e-08, 'lambda_l2': 0.006056316056813106}. Best is trial 43 with value: 0.5163933642414065.
# regularization_factors, val_score: 0.516393:  50%|#####     | 10/20 [01:20<01:20,  8.05s/it][I 2023-07-12 12:03:03,121] Trial 52 finished with value: 0.5163933017410901 and parameters: {'lambda_l1': 2.6214198379255157e-08, 'lambda_l2': 0.008763220041449554}. Best is trial 43 with value: 0.5163933642414065.
# regularization_factors, val_score: 0.516394:  55%|#####5    | 11/20 [01:26<01:07,  7.50s/it][I 2023-07-12 12:03:09,390] Trial 53 finished with value: 0.516393614242672 and parameters: {'lambda_l1': 2.9526877775091733e-08, 'lambda_l2': 0.009984935662663617}. Best is trial 53 with value: 0.516393614242672.
# regularization_factors, val_score: 0.516394:  60%|######    | 12/20 [01:35<01:02,  7.83s/it][I 2023-07-12 12:03:17,955] Trial 54 finished with value: 0.5159217993541092 and parameters: {'lambda_l1': 4.0084293218432315e-08, 'lambda_l2': 0.018392425406132274}. Best is trial 53 with value: 0.516393614242672.
# regularization_factors, val_score: 0.516394:  65%|######5   | 13/20 [01:44<00:56,  8.02s/it][I 2023-07-12 12:03:26,417] Trial 55 finished with value: 0.5159232368613866 and parameters: {'lambda_l1': 6.884704536097945e-07, 'lambda_l2': 0.04549427126118625}. Best is trial 53 with value: 0.516393614242672.
# regularization_factors, val_score: 0.516394:  70%|#######   | 14/20 [01:50<00:44,  7.47s/it][I 2023-07-12 12:03:32,621] Trial 56 finished with value: 0.5153135462748281 and parameters: {'lambda_l1': 0.005643528857620114, 'lambda_l2': 0.00012060949422464471}. Best is trial 53 with value: 0.516393614242672.
# regularization_factors, val_score: 0.516394:  75%|#######5  | 15/20 [01:58<00:39,  7.81s/it][I 2023-07-12 12:03:41,227] Trial 57 finished with value: 0.5156761731106264 and parameters: {'lambda_l1': 7.156359880218493e-07, 'lambda_l2': 0.3091677008876538}. Best is trial 53 with value: 0.516393614242672.
# regularization_factors, val_score: 0.516394:  80%|########  | 16/20 [02:05<00:29,  7.36s/it][I 2023-07-12 12:03:47,543] Trial 58 finished with value: 0.5163925517372931 and parameters: {'lambda_l1': 5.682553973516562e-07, 'lambda_l2': 0.0005413523165286821}. Best is trial 53 with value: 0.516393614242672.
# regularization_factors, val_score: 0.516394:  85%|########5 | 17/20 [02:13<00:23,  7.70s/it][I 2023-07-12 12:03:56,023] Trial 59 finished with value: 0.5159659245774931 and parameters: {'lambda_l1': 2.9893539946661964e-07, 'lambda_l2': 0.18891362124605518}. Best is trial 53 with value: 0.516393614242672.
# regularization_factors, val_score: 0.516394:  90%|######### | 18/20 [02:22<00:15,  7.96s/it][I 2023-07-12 12:04:04,590] Trial 60 finished with value: 0.5163925517372931 and parameters: {'lambda_l1': 1.8806599247249772e-05, 'lambda_l2': 0.0006340213410440511}. Best is trial 53 with value: 0.516393614242672.
# regularization_factors, val_score: 0.516394:  95%|#########5| 19/20 [02:28<00:07,  7.46s/it][I 2023-07-12 12:04:10,885] Trial 61 finished with value: 0.5163932392407736 and parameters: {'lambda_l1': 1.0116355307691931e-08, 'lambda_l2': 0.00618357815448977}. Best is trial 53 with value: 0.516393614242672.
# regularization_factors, val_score: 0.516394: 100%|##########| 20/20 [02:37<00:00,  7.79s/it][I 2023-07-12 12:04:19,454] Trial 62 finished with value: 0.5159220493553749 and parameters: {'lambda_l1': 1.1252547613241052e-08, 'lambda_l2': 0.015664420409324628}. Best is trial 53 with value: 0.516393614242672.
# regularization_factors, val_score: 0.516394: 100%|##########| 20/20 [02:37<00:00,  7.85s/it]
# min_data_in_leaf, val_score: 0.516394:  20%|##        | 1/5 [00:06<00:25,  6.28s/it][I 2023-07-12 12:04:25,751] Trial 63 finished with value: 0.516393614242672 and parameters: {'min_child_samples': 5}. Best is trial 63 with value: 0.516393614242672.
# min_data_in_leaf, val_score: 0.516394:  40%|####      | 2/5 [00:14<00:22,  7.56s/it][I 2023-07-12 12:04:34,199] Trial 64 finished with value: 0.516025362378397 and parameters: {'min_child_samples': 25}. Best is trial 63 with value: 0.516393614242672.
# min_data_in_leaf, val_score: 0.516394:  60%|######    | 3/5 [00:23<00:16,  8.01s/it][I 2023-07-12 12:04:42,756] Trial 65 finished with value: 0.5154604845187029 and parameters: {'min_child_samples': 100}. Best is trial 63 with value: 0.516393614242672.
# min_data_in_leaf, val_score: 0.516394:  80%|########  | 4/5 [00:29<00:07,  7.31s/it][I 2023-07-12 12:04:49,004] Trial 66 finished with value: 0.516393614242672 and parameters: {'min_child_samples': 10}. Best is trial 63 with value: 0.516393614242672.
# min_data_in_leaf, val_score: 0.516394: 100%|##########| 5/5 [00:38<00:00,  7.77s/it][I 2023-07-12 12:04:57,585] Trial 67 finished with value: 0.5154604845187029 and parameters: {'min_child_samples': 50}. Best is trial 63 with value: 0.516393614242672.
# min_data_in_leaf, val_score: 0.516394: 100%|##########| 5/5 [00:38<00:00,  7.62s/it]

# %%
i = 0
result = []
kf = KFold(n_splits=5, shuffle=False)
for learn_index, valid_index in kf.split(X_train, Y_train):
  X_learn, X_valid = X_train[learn_index], X_train[valid_index]
  y_learn, y_valid = Y_train[learn_index], Y_train[valid_index]
  y_pred_learn = bests_[i].predict(X_learn, num_iteration=bests_[i].best_iteration)
  y_pred_valid = bests_[i].predict(X_valid, num_iteration=bests_[i].best_iteration)
  result.append([accuracy_score(y_learn, np.round(y_pred_learn)), accuracy_score(y_valid, np.round(y_pred_valid))])
  i=i+1
print(result)
# Out:
# [[0.67359375, 0.520625], [0.6039375, 0.519375], [0.71078125, 0.522], [0.54646875, 0.521125], [0.54984375, 0.51525]]

# %%
lgb.plot_importance(bests_[0], figsize=(12, 6))
plt.show()

# %%
lgb.plot_importance(bests_[1], figsize=(12, 6))
plt.show()

# %%
lgb.plot_importance(bests_[2], figsize=(12, 6))
plt.show()

# %%
lgb.plot_importance(bests_[3], figsize=(12, 6))
plt.show()

# %%
lgb.plot_importance(bests_[4], figsize=(12, 6))
plt.show()

# %%
y_preds = []
for i in range(5):
    y_pred = bests_[i].predict(X_train, num_iteration=bests_[i].best_iteration)
    y_preds.append(y_pred)
y_pred = (y_preds[0] + y_preds[1]+ y_preds[2]+ y_preds[3]+ y_preds[4])/5

accuracy_score(Y_train, np.round(y_pred))
# Out:
# 0.6465

# %%
y_preds = []
for i in range(5):
    y_pred = bests_[i].predict(X_test, num_iteration=bests_[i].best_iteration)
    y_preds.append(y_pred)
y_pred = (y_preds[0] + y_preds[1]+ y_preds[2]+ y_preds[3]+ y_preds[4])/5
accuracy_score(Y_test, np.round(y_pred))
# Out:
# 0.512327455517434

# %%
cm = confusion_matrix(np.round(y_pred), Y_test)
cm_matrix = pd.DataFrame(data=cm, columns=['Actual :0', 'Actual :1'],
                                 index=['Predict :0', 'Predict :1'])

sns.heatmap(cm_matrix, annot=True, fmt='d', cmap='YlGnBu')
# Out:
# <Axes: >
